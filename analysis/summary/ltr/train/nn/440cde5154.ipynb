# %%
MAIN_PATH = "/home/carlos/MasterDS/tfm"
JSON_DATA_PATH = '{}/data/json/'.format(MAIN_PATH)
CSV_DATA_PATH = '{}/data/csv/'.format(MAIN_PATH)

# %%
import sys
sys.path.insert(0, MAIN_PATH)

# %%
# %load_ext autoreload
# %autoreload 2
from scripts.models.ltr_nn_tf.train import LTRNNTFTrain
from scripts.models.ltr_nn_tf.metrics import LTRNNTFMetrics

# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Entrenamiento

# %%
ltr_params = {
    'mode': 'tfidf',
    'count_vec_kwargs': {'strip_accents': 'unicode'},
    'target_metric': 'cosine_emb',
    'metric_params': {'embedding': 'distilroberta-base-paraphrase-v1',
                     'text_process': 'basic'},
    'drop_teams': True,
    'lemma': True,
    'train_perc': 0.7,
    'val_perc': 0.2
}
DENSE_LAYERS = [125, 60, 20]
N_DROPOUT = 3

model_params = {
    'dense_layers': DENSE_LAYERS,
    'dense_activation': ['relu'] * len(DENSE_LAYERS),
    'dropout': [0.3] * N_DROPOUT,
    'optimizer': 'adam',
}

dim_reduction_params = {
        'dim_reduction': 'truncated_svd',
        'dim_reduction_params': {
            'n_components': 250,
            'random_state': 10
    }
}

opt_metric = 'mean_squared_error'
epochs = 25
batch_size = 128
# Not in config
shuffle = True
max_queue_size = 50

# %%
ltr_train = LTRNNTFTrain(ltr_params, epochs=epochs, batch_size=batch_size,
                         model_params=model_params,
                         opt_metric=opt_metric, 
                        dim_reduction_params=dim_reduction_params)
# Out:
# Using truncated_svd for dimensionality reduction
# Using truncated_svd for dimensionality reduction
# Setting target metric to cosine_emb
# Setting mode to tfidf
# Optimizing mean_squared_error with adam
# Epochs: 25
# Batch size: 128

# %%
ltr_train.train()
# Out:
# Writing config in /home/carlos/MasterDS/tfm/models/ltr_nn_tfidf/440cde5154/config.pickle
# Loading training data from /home/carlos/MasterDS/tfm/data/ltr/features_targets/c04dabab1a
# Loading validation data from /home/carlos/MasterDS/tfm/data/ltr/features_targets/c04dabab1a
# Training truncated_svd with the following parameters:{'n_components': 250, 'random_state': 10}
# Train shape before: (339040, 6550)
# Validation shape before: (42380, 6550)
# Train shape after: (339040, 250)
# Validation shape after: (42380, 250)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 125)               31375
# _________________________________________________________________
# dropout (Dropout)            (None, 125)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 60)                7560
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                1220
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 40,176
# Trainable params: 40,176
# Non-trainable params: 0
# _________________________________________________________________
# Training model...
# Epoch 1/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - mean_absolute_error: 0.0710 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0624
# Epoch 2/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - mean_absolute_error: 0.0631 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - val_mean_absolute_error: 0.0613
# Epoch 3/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0625 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - val_mean_absolute_error: 0.0607
# Epoch 4/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0622 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - val_mean_absolute_error: 0.0605
# Epoch 5/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0620 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - val_mean_absolute_error: 0.0600
# Epoch 6/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0617 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - val_mean_absolute_error: 0.0600
# Epoch 7/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0617 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - val_mean_absolute_error: 0.0612
# Epoch 8/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0616 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - val_mean_absolute_error: 0.0610
# Epoch 9/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - mean_absolute_error: 0.0614 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - val_mean_absolute_error: 0.0601
# Epoch 10/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - mean_absolute_error: 0.0613 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - val_mean_absolute_error: 0.0604
# Epoch 11/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - mean_absolute_error: 0.0612 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - val_mean_absolute_error: 0.0601
# Epoch 12/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - mean_absolute_error: 0.0611 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - val_mean_absolute_error: 0.0605
# Epoch 13/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - mean_absolute_error: 0.0612 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - val_mean_absolute_error: 0.0599
# Epoch 14/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - mean_absolute_error: 0.0610 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - val_mean_absolute_error: 0.0600
# Epoch 15/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - mean_absolute_error: 0.0611 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - val_mean_absolute_error: 0.0605
# Epoch 16/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - mean_absolute_error: 0.0610 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - val_mean_absolute_error: 0.0600
# Epoch 17/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - mean_absolute_error: 0.0610 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - val_mean_absolute_error: 0.0604
# Epoch 18/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0609 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - val_mean_absolute_error: 0.0595
# Epoch 19/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0609 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - val_mean_absolute_error: 0.0598
# Epoch 20/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0608 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - val_mean_absolute_error: 0.0603
# Epoch 21/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0608 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - val_mean_absolute_error: 0.0596
# Epoch 22/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0608 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - val_mean_absolute_error: 0.0599
# Epoch 23/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0608 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - val_mean_absolute_error: 0.0603
# Epoch 24/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0607 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - val_mean_absolute_error: 0.0605
# Epoch 25/25
# 2649/2649 [==============================] - 7s 3ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0607 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - val_mean_absolute_error: 0.0602

# %%
X_train, y_train = ltr_train.train_data()
# Out:
# Loading training data from /home/carlos/MasterDS/tfm/data/ltr/features_targets/98a1222ae6

# %%
type(y_train)
# Out:
# numpy.ndarray

# %%
type(X_train)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
X_train.shape
# Out:
# (339040, 6550)

# %% [markdown]
# ## Métricas

# %% [markdown]
# Usando el objeto history de Keras:

# %% [markdown]
# Usando nuestros procesos:

# %%
ltr_metrics = LTRNNTFMetrics(ltr_train)

# %%
ltr_metrics.run()
# Out:
# Computing metric for train dataset
# Reducing x dimension
# Shape before: (339040, 6550)
# Shape after: (339040, 250)
# Writing metrics to /home/carlos/MasterDS/tfm/models/ltr_nn_tfidf/440cde5154/train_metrics.pickle
# Computing metric for validation dataset
# Reducing x dimension
# Shape before: (42380, 6550)
# Shape after: (42380, 250)
# Writing metrics to /home/carlos/MasterDS/tfm/models/ltr_nn_tfidf/440cde5154/validation_metrics.pickle
# Computing metric for test dataset
# Reducing x dimension
# Shape before: (42380, 6550)
# Shape after: (42380, 250)
# Writing metrics to /home/carlos/MasterDS/tfm/models/ltr_nn_tfidf/440cde5154/test_metrics.pickle

# %%
ltr_metrics.show_metrics('train')
# Out:
# Reading metrics from /home/carlos/MasterDS/tfm/models/ltr_nn_tfidf/440cde5154/train_metrics.pickle
# mse : 0.005762520993036164
# mae : 0.059323545803006
# r2 : 0.4631396504128582

# %%
ltr_metrics.show_metrics('validation')
# Out:
# Reading metrics from /home/carlos/MasterDS/tfm/models/ltr_nn_tfidf/440cde5154/validation_metrics.pickle
# mse : 0.005911239395036228
# mae : 0.060180339801262354
# r2 : 0.4475217948372705

# %%
ltr_metrics.show_metrics_history()
