# %%
MAIN_PATH = "/home/carlos/MasterDS/tfm"
JSON_DATA_PATH = '{}/data/json/'.format(MAIN_PATH)
CSV_DATA_PATH = '{}/data/csv/'.format(MAIN_PATH)

# %%
import sys
sys.path.insert(0, MAIN_PATH)

# %%
# %load_ext autoreload
# %autoreload 2
from scripts.models.ltr_nn_tf.train import LTRNNTFTrain
from scripts.models.ltr_nn_tf.metrics import LTRNNTFMetrics

# %reload_ext autoreload

# %% [markdown]
# # Entrenamiento

# %%
ltr_params = {
    'mode': 'tfidf',
    'count_vec_kwargs': {'strip_accents': 'unicode'},
    'target_metric': 'rouge',
    'metric_params': {'rouge_mode': 'rouge-1', 'rouge_metric': 'r'},
    'drop_teams': True,
    'lemma': True,
    'train_perc': 0.7,
    'val_perc': 0.2
}
DENSE_LAYERS = [125, 60, 20]
N_DROPOUT = 3

model_params = {
    'dense_layers': DENSE_LAYERS,
    'dense_activation': ['relu'] * len(DENSE_LAYERS),
    'dropout': [0.3] * N_DROPOUT,
    'optimizer': 'adam',
}

dim_reduction_params = {
        'dim_reduction': 'truncated_svd',
        'dim_reduction_params': {
            'n_components': 250,
            'random_state': 10
    }
}

opt_metric = 'mean_squared_error'
epochs = 25
batch_size = 128

# %%
ltr_train = LTRNNTFTrain(ltr_params, epochs=epochs, batch_size=batch_size,
                         model_params=model_params,
                         opt_metric=opt_metric, 
                        dim_reduction_params=dim_reduction_params)
# Out:
# Using truncated_svd for dimensionality reduction
# Using truncated_svd for dimensionality reduction
# Setting target metric to rouge
# Setting mode to tfidf
# Optimizing mean_squared_error with adam
# Epochs: 25
# Batch size: 128

# %%
ltr_train.experiment_id()
# Out:
# 'b7169c31f0'

# %%
ltr_train.train()
# Out:
# Loading training data from /home/carlos/MasterDS/tfm/data/ltr/features_targets/98a1222ae6
# Loading validation data from /home/carlos/MasterDS/tfm/data/ltr/features_targets/98a1222ae6
# Training truncated_svd with the following parameters:{'n_components': 250, 'random_state': 10}
# Train shape before: (339040, 6550)
# Validation shape before: (42380, 6550)
# Train shape after: (339040, 250)
# Validation shape after: (42380, 250)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 125)               31375
# _________________________________________________________________
# dropout (Dropout)            (None, 125)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 60)                7560
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                1220
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 40,176
# Trainable params: 40,176
# Non-trainable params: 0
# _________________________________________________________________
# Training model...
# Epoch 1/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0153 - mean_squared_error: 0.0153 - mean_absolute_error: 0.0849 - val_loss: 0.0149 - val_mean_squared_error: 0.0149 - val_mean_absolute_error: 0.0823
# Epoch 2/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - mean_absolute_error: 0.0828 - val_loss: 0.0148 - val_mean_squared_error: 0.0148 - val_mean_absolute_error: 0.0808
# Epoch 3/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - mean_absolute_error: 0.0824 - val_loss: 0.0145 - val_mean_squared_error: 0.0145 - val_mean_absolute_error: 0.0812
# Epoch 4/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - mean_absolute_error: 0.0820 - val_loss: 0.0145 - val_mean_squared_error: 0.0145 - val_mean_absolute_error: 0.0824
# Epoch 5/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - mean_absolute_error: 0.0818 - val_loss: 0.0145 - val_mean_squared_error: 0.0145 - val_mean_absolute_error: 0.0812
# Epoch 6/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - mean_absolute_error: 0.0817 - val_loss: 0.0144 - val_mean_squared_error: 0.0144 - val_mean_absolute_error: 0.0806
# Epoch 7/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - mean_absolute_error: 0.0815 - val_loss: 0.0145 - val_mean_squared_error: 0.0145 - val_mean_absolute_error: 0.0806
# Epoch 8/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - mean_absolute_error: 0.0815 - val_loss: 0.0144 - val_mean_squared_error: 0.0144 - val_mean_absolute_error: 0.0812
# Epoch 9/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0142 - mean_squared_error: 0.0142 - mean_absolute_error: 0.0813 - val_loss: 0.0144 - val_mean_squared_error: 0.0144 - val_mean_absolute_error: 0.0814
# Epoch 10/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0142 - mean_squared_error: 0.0142 - mean_absolute_error: 0.0813 - val_loss: 0.0144 - val_mean_squared_error: 0.0144 - val_mean_absolute_error: 0.0804
# Epoch 11/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0142 - mean_squared_error: 0.0142 - mean_absolute_error: 0.0811 - val_loss: 0.0144 - val_mean_squared_error: 0.0144 - val_mean_absolute_error: 0.0811
# Epoch 12/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - mean_absolute_error: 0.0811 - val_loss: 0.0145 - val_mean_squared_error: 0.0145 - val_mean_absolute_error: 0.0818
# Epoch 13/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - mean_absolute_error: 0.0810 - val_loss: 0.0143 - val_mean_squared_error: 0.0143 - val_mean_absolute_error: 0.0815
# Epoch 14/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - mean_absolute_error: 0.0810 - val_loss: 0.0145 - val_mean_squared_error: 0.0145 - val_mean_absolute_error: 0.0806
# Epoch 15/25
# 2649/2649 [==============================] - 7s 2ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - mean_absolute_error: 0.0809 - val_loss: 0.0145 - val_mean_squared_error: 0.0145 - val_mean_absolute_error: 0.0805
# Epoch 16/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - mean_absolute_error: 0.0809 - val_loss: 0.0144 - val_mean_squared_error: 0.0144 - val_mean_absolute_error: 0.0808
# Epoch 17/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - mean_absolute_error: 0.0809 - val_loss: 0.0144 - val_mean_squared_error: 0.0144 - val_mean_absolute_error: 0.0810
# Epoch 18/25
# 2649/2649 [==============================] - 6s 2ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - mean_absolute_error: 0.0808 - val_loss: 0.0144 - val_mean_squared_error: 0.0144 - val_mean_absolute_error: 0.0810

# %% [markdown]
# ## Métricas

# %% [markdown]
# Usando nuestros procesos:

# %%
ltr_metrics = LTRNNTFMetrics(ltr_train)

# %%
ltr_metrics.run()
# Out:
# Computing metric for train dataset
# Computing metric for validation dataset
# Computing metric for test dataset

# %%
ltr_metrics.show_metrics('train')
# Out:
# Reading metrics from /home/carlos/MasterDS/tfm/models/ltr_nn_tfidf/b7169c31f0/train_metrics.pickle
# mse : 0.013248400714338738
# mae : 0.0775884401894828
# r2 : 0.28334172550816816

# %%
ltr_metrics.show_metrics('validation')
# Out:
# Reading metrics from /home/carlos/MasterDS/tfm/models/ltr_nn_tfidf/b7169c31f0/validation_metrics.pickle
# mse : 0.014430653857259447
# mae : 0.08009784911771838
# r2 : 0.24013676858576116

# %%
ltr_metrics.show_metrics_history()
