# %%
MAIN_PATH = "/home/carlos/PycharmProjects/tfm"
DATA_PATH = '{}/data/json'.format(MAIN_PATH)

# %%
import sys
sys.path.insert(0, MAIN_PATH)

# %%
import json
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2
from scripts.text.article_text_processor import ArticleTextProcessor
from scripts.text.teams_players import TeamPlayers

# %%
# %reload_ext autoreload

# %% [markdown]
# # Procesamiento de noticias y eventos

# %% [markdown]
# ## Procesamiento básico

# %%
processor = ArticleTextProcessor()

# %%
all_files = processor.load_json()

# %%
all_files.keys()
# Out:
# dict_keys(['italian_serie_a_2019_2020.json', 'champions_league_2019_2020.json', 'mls_2018_2019.json', 'spanish_la_liga_2019_2020.json', 'italian_serie_a_2017_2018.json', 'german_bundesliga_2017_2018.json', 'german_bundesliga_2019_2020.json', 'mls_2016_2017.json', 'mls_2017_2018.json', 'spanish_la_liga_2017_2018.json', 'premier_league_2016_2017.json', 'german_bundesliga_2018_2019.json', 'italian_serie_a_2018_2019.json', 'premier_league_2019_2020.json', 'premier_league_2018_2019.json', 'french_ligue_one_2019_2020.json', 'spanish_la_liga_2018_2019.json', 'premier_league_2017_2018.json', 'mls_2019_2020.json'])

# %%
prueba = all_files['premier_league_2019_2020.json']['https://www.bbc.com/sport/football/49791610']

# %%
prueba['events']
# Out:
# ['Lineups are announced and players are warming up.',
#  'First Half begins.',
#  'Foul by Matteo Guendouzi (Arsenal).',
#  'Scott McTominay (Manchester United) wins a free kick in the defensive half.',
#  'Granit Xhaka (Arsenal) wins a free kick in the defensive half.',
#  'Foul by Jesse Lingard (Manchester United).',
#  'Corner,  Arsenal. Conceded by Axel Tuanzebe.',
#  'Hand ball by Bukayo Saka (Arsenal).',
#  'Corner,  Manchester United. Conceded by Calum Chambers.',
#  'Foul by Calum Chambers (Arsenal).',
#  'Daniel James (Manchester United) wins a free kick on the left wing.',
#  'Calum Chambers (Arsenal) is shown the yellow card for a bad foul.',
#  'Offside, Manchester United. Ashley Young tries a through ball, but Harry Maguire is caught offside.',
#  'Hand ball by Andreas Pereira (Manchester United).',
#  'Offside, Arsenal. Bernd Leno tries a through ball, but Bukayo Saka is caught offside.',
#  'Pierre-Emerick Aubameyang (Arsenal) wins a free kick on the left wing.',
#  'Foul by Paul Pogba (Manchester United).',
#  'Bukayo Saka (Arsenal) wins a free kick in the attacking half.',
#  'Foul by Jesse Lingard (Manchester United).',
#  'Matteo Guendouzi (Arsenal) wins a free kick in the defensive half.',
#  'Foul by Andreas Pereira (Manchester United).',
#  'Bukayo Saka (Arsenal) wins a free kick on the left wing.',
#  'Foul by Ashley Young (Manchester United).',
#  'Sokratis (Arsenal) wins a free kick in the defensive half.',
#  'Foul by Marcus Rashford (Manchester United).',
#  'Marcus Rashford (Manchester United) is shown the yellow card for a bad foul.',
#  'Foul by Lucas Torreira (Arsenal).',
#  'Axel Tuanzebe (Manchester United) wins a free kick in the defensive half.',
#  'Attempt saved. Andreas Pereira (Manchester United) left footed shot from the centre of the box is saved in the bottom right corner.',
#  'Attempt missed. Nicolas Pépé (Arsenal) left footed shot from outside the box is high and wide to the left. Assisted by Bukayo Saka.',
#  'Offside, Arsenal. Bukayo Saka tries a through ball, but Sead Kolasinac is caught offside.',
#  'Matteo Guendouzi (Arsenal) wins a free kick in the attacking half.',
#  'Foul by Andreas Pereira (Manchester United).',
#  'Andreas Pereira (Manchester United) is shown the yellow card for a bad foul.',
#  'Attempt saved. Nicolas Pépé (Arsenal) left footed shot from the centre of the box is saved in the bottom right corner. Assisted by Pierre-Emerick Aubameyang.',
#  'Attempt blocked. Paul Pogba (Manchester United) right footed shot from outside the box is blocked.',
#  'Foul by Nicolas Pépé (Arsenal).',
#  'Scott McTominay (Manchester United) wins a free kick in the attacking half.',
#  'Offside, Manchester United. Ashley Young tries a through ball, but Harry Maguire is caught offside.',
#  'Foul by Bukayo Saka (Arsenal).',
#  'Ashley Young (Manchester United) wins a free kick in the defensive half.',
#  'Matteo Guendouzi (Arsenal) wins a free kick in the defensive half.',
#  'Foul by Ashley Young (Manchester United).',
#  'Ashley Young (Manchester United) is shown the yellow card for a bad foul.',
#  'Attempt blocked. Marcus Rashford (Manchester United) left footed shot from the left side of the box is blocked. Assisted by Paul Pogba with a through ball.',
#  'Attempt blocked. Andreas Pereira (Manchester United) right footed shot from the right side of the box is blocked. Assisted by Jesse Lingard.',
#  'Corner,  Manchester United. Conceded by Sead Kolasinac.',
#  'Attempt saved. Bukayo Saka (Arsenal) left footed shot from the centre of the box is saved in the bottom right corner.',
#  'Attempt saved. Matteo Guendouzi (Arsenal) right footed shot from a difficult angle on the right is saved in the bottom right corner.',
#  'Corner,  Arsenal. Conceded by David de Gea.',
#  'Goal!  Manchester United 1, Arsenal 0. Scott McTominay (Manchester United) right footed shot from outside the box to the top left corner. Assisted by Marcus Rashford.',
#  'First Half ends, Manchester United 1, Arsenal 0.',
#  'Second Half begins Manchester United 1, Arsenal 0.',
#  'Corner,  Arsenal. Conceded by Axel Tuanzebe.',
#  'Attempt missed. Lucas Torreira (Arsenal) right footed shot from the centre of the box misses to the right. Assisted by Pierre-Emerick Aubameyang with a cross.',
#  'Corner,  Manchester United. Conceded by Sead Kolasinac.',
#  'Bukayo Saka (Arsenal) wins a free kick in the attacking half.',
#  'Foul by Scott McTominay (Manchester United).',
#  'Substitution, Arsenal. Dani Ceballos replaces Lucas Torreira.',
#  'Attempt blocked. David Luiz (Arsenal) right footed shot from outside the box is blocked.',
#  'Corner,  Arsenal. Conceded by Victor Lindelöf.',
#  'Corner,  Manchester United. Conceded by Matteo Guendouzi.',
#  'Attempt missed. Andreas Pereira (Manchester United) right footed shot from outside the box is too high. Assisted by Scott McTominay following a corner.',
#  'Goal!  Manchester United 1, Arsenal 1. Pierre-Emerick Aubameyang (Arsenal) left footed shot from the centre of the box to the centre of the goal. Assisted by Bukayo Saka with a through ball.Goal awarded following VAR Review.',
#  'VAR Decision: Goal  Manchester United 1-1 Arsenal (Pierre-Emerick Aubameyang).',
#  'Attempt blocked. Bukayo Saka (Arsenal) right footed shot from the centre of the box is blocked. Assisted by Calum Chambers.',
#  'Corner,  Arsenal. Conceded by Victor Lindelöf.',
#  'Offside, Arsenal. Granit Xhaka tries a through ball, but Pierre-Emerick Aubameyang is caught offside.',
#  'Attempt blocked. Daniel James (Manchester United) left footed shot from outside the box is blocked. Assisted by Andreas Pereira.',
#  'Matteo Guendouzi (Arsenal) wins a free kick in the defensive half.',
#  'Foul by Axel Tuanzebe (Manchester United).',
#  'Attempt blocked. Andreas Pereira (Manchester United) left footed shot from outside the box is blocked. Assisted by Marcus Rashford.',
#  'Attempt missed. Paul Pogba (Manchester United) right footed shot from outside the box is close, but misses to the right.',
#  'Matteo Guendouzi (Arsenal) wins a free kick in the defensive half.',
#  'Foul by Jesse Lingard (Manchester United).',
#  'Jesse Lingard (Manchester United) is shown the yellow card for a bad foul.',
#  'Corner,  Manchester United. Conceded by Sokratis.',
#  'Attempt missed. Scott McTominay (Manchester United) header from very close range is just a bit too high. Assisted by Ashley Young with a cross following a corner.',
#  'Attempt missed. Marcus Rashford (Manchester United) right footed shot from outside the box misses to the left. Assisted by Paul Pogba.',
#  'Foul by Granit Xhaka (Arsenal).',
#  'Scott McTominay (Manchester United) wins a free kick in the attacking half.',
#  'Corner,  Manchester United. Conceded by David Luiz.',
#  'Attempt saved. Harry Maguire (Manchester United) right footed shot from outside the box is saved in the top right corner. Assisted by Andreas Pereira.',
#  'Corner,  Manchester United. Conceded by Bernd Leno.',
#  'Bernd Leno (Arsenal) wins a free kick in the defensive half.',
#  'Foul by Harry Maguire (Manchester United).',
#  'Substitution, Manchester United. Fred replaces Jesse Lingard.',
#  'Substitution, Manchester United. Mason Greenwood replaces Andreas Pereira.',
#  'Substitution, Arsenal. Reiss Nelson replaces Nicolas Pépé.',
#  'Matteo Guendouzi (Arsenal) wins a free kick in the defensive half.',
#  'Foul by Fred (Manchester United).',
#  'Foul by Matteo Guendouzi (Arsenal).',
#  'Daniel James (Manchester United) wins a free kick in the defensive half.',
#  'Foul by Granit Xhaka (Arsenal).',
#  'Mason Greenwood (Manchester United) wins a free kick in the attacking half.',
#  'Granit Xhaka (Arsenal) is shown the yellow card.',
#  'Corner,  Manchester United. Conceded by Calum Chambers.',
#  'Attempt missed. Fred (Manchester United) right footed shot from outside the box is high and wide to the right following a corner.',
#  'Substitution, Arsenal. Joe Willock replaces Bukayo Saka.',
#  'Foul by Reiss Nelson (Arsenal).',
#  'Paul Pogba (Manchester United) wins a free kick in the defensive half.',
#  'Foul by Dani Ceballos (Arsenal).',
#  'Scott McTominay (Manchester United) wins a free kick on the right wing.',
#  'Bernd Leno (Arsenal) wins a free kick in the defensive half.',
#  'Foul by Marcus Rashford (Manchester United).',
#  'David Luiz (Arsenal) wins a free kick in the defensive half.',
#  'Foul by Marcus Rashford (Manchester United).',
#  'Offside, Arsenal. Joe Willock tries a through ball, but Pierre-Emerick Aubameyang is caught offside.',
#  'Corner,  Arsenal. Conceded by Axel Tuanzebe.',
#  'Corner,  Arsenal. Conceded by Axel Tuanzebe.',
#  'Attempt missed. Dani Ceballos (Arsenal) right footed shot from the centre of the box misses to the right. Assisted by Joe Willock following a fast break.',
#  'Foul by Calum Chambers (Arsenal).',
#  'Daniel James (Manchester United) wins a free kick on the left wing.',
#  'Attempt blocked. Scott McTominay (Manchester United) right footed shot from outside the box is blocked. Assisted by Ashley Young.',
#  'Foul by David Luiz (Arsenal).',
#  'Scott McTominay (Manchester United) wins a free kick in the attacking half.',
#  'Attempt saved. Marcus Rashford (Manchester United) right footed shot from outside the box is saved in the bottom right corner.',
#  'Attempt saved. Reiss Nelson (Arsenal) left footed shot from outside the box is saved in the bottom right corner. Assisted by Joe Willock.',
#  'Attempt missed. Mason Greenwood (Manchester United) right footed shot from outside the box misses to the left. Assisted by Fred.',
#  'Dani Ceballos (Arsenal) wins a free kick on the left wing.',
#  'Foul by Mason Greenwood (Manchester United).',
#  'Reiss Nelson (Arsenal) wins a free kick on the right wing.',
#  'Foul by Axel Tuanzebe (Manchester United).',
#  'Second Half ends, Manchester United 1, Arsenal 1.',
#  'Match ends, Manchester United 1, Arsenal 1.']

# %%
processor._clean_tokens(prueba['article'])
# Out:
# ['manchester',
#  'united',
#  'and',
#  'arsenal',
#  'played',
#  'out',
#  'a',
#  'grim',
#  'stalemate',
#  'at',
#  'old',
#  'trafford',
#  'that',
#  'provided',
#  'compelling',
#  'evidence',
#  'to',
#  'illustrate',
#  'just',
#  'how',
#  'far',
#  'away',
#  'from',
#  'a',
#  'premier',
#  'league',
#  'challenge',
#  'both',
#  'clubs',
#  'are',
#  'in',
#  'a',
#  'disappointing',
#  'encounter',
#  'that',
#  'was',
#  'a',
#  'pale',
#  'shadow',
#  'of',
#  'their',
#  'mighty',
#  'clashes',
#  'of',
#  'years',
#  'gone',
#  'by',
#  'scott',
#  'mctominay',
#  'gave',
#  'manchester',
#  'united',
#  'the',
#  'lead',
#  'at',
#  'the',
#  'end',
#  'of',
#  'an',
#  'attritional',
#  'first',
#  'half',
#  'with',
#  'a',
#  'rising',
#  'drive',
#  'from',
#  'the',
#  'edge',
#  'of',
#  'the',
#  'area',
#  'arsenal',
#  'equalised',
#  'just',
#  'before',
#  'the',
#  'hour',
#  'courtesy',
#  'of',
#  'pierre',
#  'emerick',
#  'aubameyang',
#  'cool',
#  'finish',
#  'it',
#  'was',
#  'originally',
#  'ruled',
#  'out',
#  'for',
#  'offside',
#  'but',
#  'the',
#  'video',
#  'assistant',
#  'referee',
#  'confirmed',
#  'the',
#  'striker',
#  'had',
#  'been',
#  'played',
#  'onside',
#  'by',
#  'harry',
#  'maguire',
#  'goalkeeper',
#  'bernd',
#  'leno',
#  'excelled',
#  'for',
#  'arsenal',
#  'with',
#  'fine',
#  'saves',
#  'from',
#  'maguire',
#  'and',
#  'marcus',
#  'rashford',
#  'late',
#  'free',
#  'kick',
#  'while',
#  'bukayo',
#  'saka',
#  'goalbound',
#  'shot',
#  'crucially',
#  'struck',
#  'victor',
#  'lindelof',
#  'and',
#  'flew',
#  'over',
#  'the',
#  'top',
#  'mctominay',
#  'also',
#  'headed',
#  'a',
#  'great',
#  'chance',
#  'well',
#  'over',
#  'from',
#  'ashley',
#  'young',
#  'corner',
#  'but',
#  'neither',
#  'side',
#  'could',
#  'force',
#  'a',
#  'winner',
#  'the',
#  'result',
#  'takes',
#  'arsenal',
#  'into',
#  'the',
#  'top',
#  'four',
#  'but',
#  'manchester',
#  'united',
#  'are',
#  'now',
#  'down',
#  'in',
#  '10th',
#  'after',
#  'an',
#  'outcome',
#  'that',
#  'means',
#  'they',
#  'have',
#  'made',
#  'their',
#  'worst',
#  'start',
#  'after',
#  'seven',
#  'games',
#  'in',
#  '30',
#  'years',
#  'failing',
#  'to',
#  'reach',
#  'double',
#  'figures',
#  'for',
#  'the',
#  'first',
#  'time',
#  'since',
#  '1989',
#  '90',
#  'a',
#  'season',
#  'in',
#  'which',
#  'they',
#  'finished',
#  '13th',
#  'the',
#  'current',
#  'circumstances',
#  'of',
#  'both',
#  'clubs',
#  'was',
#  'instantly',
#  'demonstrated',
#  'by',
#  'the',
#  'two',
#  'captains',
#  'who',
#  'led',
#  'out',
#  'the',
#  'sides',
#  'manchester',
#  'united',
#  'captain',
#  'was',
#  '34-year',
#  'old',
#  'ashley',
#  'young',
#  'pressed',
#  'into',
#  'defensive',
#  'service',
#  'by',
#  'aaron',
#  'wan',
#  'bissaka',
#  'absence',
#  'through',
#  'injury',
#  'and',
#  'arsenal',
#  'were',
#  'led',
#  'by',
#  'granit',
#  'xhaka',
#  'newly',
#  'appointed',
#  'and',
#  'a',
#  'divisive',
#  'figure',
#  'among',
#  'supporters',
#  'young',
#  'led',
#  'from',
#  'the',
#  'front',
#  'in',
#  'a',
#  'fashion',
#  'by',
#  'regularly',
#  'contesting',
#  'decisions',
#  'showing',
#  'a',
#  'remarkable',
#  'knack',
#  'of',
#  'getting',
#  'to',
#  'referee',
#  'kevin',
#  'friend',
#  'in',
#  'an',
#  'instant',
#  'on',
#  'numerous',
#  'occasions',
#  'xhaka',
#  'night',
#  'will',
#  'be',
#  'best',
#  'remembered',
#  'for',
#  'his',
#  'contribution',
#  'to',
#  'united',
#  'goal',
#  'getting',
#  'away',
#  'with',
#  'a',
#  'foul',
#  'in',
#  'the',
#  'build',
#  'up',
#  'before',
#  'appearing',
#  'to',
#  'take',
#  'evasive',
#  'action',
#  'as',
#  'mctominay',
#  'drive',
#  'made',
#  'its',
#  'way',
#  'into',
#  'the',
#  'top',
#  'corner',
#  'there',
#  'was',
#  'no',
#  'shortage',
#  'of',
#  'effort',
#  'but',
#  'this',
#  'was',
#  'a',
#  'scrappy',
#  'mess',
#  'of',
#  'a',
#  'game',
#  'lacking',
#  'any',
#  'cohesion',
#  'or',
#  'quality',
#  'united',
#  'had',
#  'the',
#  'edge',
#  'on',
#  'chances',
#  'although',
#  'they',
#  'were',
#  'grateful',
#  'to',
#  'david',
#  'de',
#  'gea',
#  'for',
#  'a',
#  'fine',
#  'double',
#  'save',
#  'from',
#  'saka',
#  'and',
#  'matteo',
#  'guendouzi',
#  'in',
#  'the',
#  'first',
#  'half',
#  'and',
#  'they',
#  'also',
#  'felt',
#  'they',
#  'had',
#  'a',
#  'respectable',
#  'appeal',
#  'for',
#  'handball',
#  'against',
#  'sead',
#  'kolasinac',
#  'ignored',
#  'by',
#  'referee',
#  'kevin',
#  'friend',
#  'arsenal',
#  'boss',
#  'unai',
#  'emery',
#  'will',
#  'be',
#  'more',
#  'satisfied',
#  'than',
#  'counterpart',
#  'ole',
#  'gunnar',
#  'solskjaer',
#  'with',
#  'a',
#  'point',
#  'but',
#  'this',
#  'showed',
#  'just',
#  'how',
#  'far',
#  'away',
#  'both',
#  'are',
#  'from',
#  'leaders',
#  'liverpool',
#  'and',
#  'reigning',
#  'champions',
#  'manchester',
#  'city',
#  'and',
#  'just',
#  'how',
#  'much',
#  'work',
#  'they',
#  'have',
#  'to',
#  'do',
#  'to',
#  'catch',
#  'up',
#  'it',
#  'was',
#  'no',
#  'surprise',
#  'when',
#  'arsenal',
#  'club',
#  'record',
#  '£',
#  '72',
#  'm',
#  'signing',
#  'nicholas',
#  'pepe',
#  'failed',
#  'to',
#  'last',
#  'the',
#  'course',
#  'being',
#  'substituted',
#  'for',
#  'reiss',
#  'nelson',
#  'after',
#  '72',
#  'minutes',
#  'the',
#  '24-year',
#  'old',
#  'signing',
#  'from',
#  'lille',
#  'had',
#  'struggled',
#  'desperately',
#  'throughout',
#  'and',
#  'looks',
#  'worryingly',
#  'short',
#  'of',
#  'confidence',
#  'so',
#  'soon',
#  'after',
#  'his',
#  'introduction',
#  'into',
#  'the',
#  'premier',
#  'league',
#  'pepe',
#  'had',
#  'one',
#  'clear',
#  'shooting',
#  'opportunity',
#  'in',
#  'the',
#  'first',
#  'half',
#  'but',
#  'skied',
#  'his',
#  'effort',
#  'hopelessly',
#  'into',
#  'the',
#  'stretford',
#  'end',
#  'he',
#  'was',
#  'on',
#  'the',
#  'periphery',
#  'of',
#  'the',
#  'action',
#  'in',
#  'a',
#  'laboured',
#  'performance',
#  'also',
#  'littered',
#  'with',
#  'poor',
#  'decision',
#  'making',
#  'it',
#  'was',
#  'left',
#  'to',
#  'the',
#  'lethal',
#  'aubameyang',
#  'to',
#  'provide',
#  'the',
#  'finishing',
#  'touch',
#  'for',
#  'arsenal',
#  'correctly',
#  'assisted',
#  'by',
#  'var',
#  'after',
#  'technology',
#  'showed',
#  'he',
#  'was',
#  'clearly',
#  'onside',
#  'solksjaer',
#  'appeared',
#  'to',
#  'think',
#  'the',
#  'linesman',
#  'raised',
#  'flag',
#  'made',
#  'his',
#  'players',
#  'stop',
#  'but',
#  'it',
#  'was',
#  'clearly',
#  'the',
#  'correct',
#  'decision',
#  'as',
#  'maguire',
#  'loitered',
#  'yards',
#  'behind',
#  'his',
#  'defensive',
#  'colleagues',
#  'manchester',
#  'united',
#  'manager',
#  'ole',
#  'gunnar',
#  'solskjaer',
#  'how',
#  'many',
#  'times',
#  'have',
#  'we',
#  'have',
#  'been',
#  '1',
#  '0',
#  'up',
#  'and',
#  'not',
#  'got',
#  'the',
#  'second',
#  'goal',
#  'this',
#  'is',
#  'a',
#  'steep',
#  'learning',
#  'curve',
#  'for',
#  'us',
#  'and',
#  'we',
#  "'ll",
#  'keep',
#  'working',
#  'hard',
#  'and',
#  'with',
#  'more',
#  'experience',
#  'we',
#  "'ll",
#  'make',
#  'the',
#  'right',
#  'decisions',
#  'we',
#  'did',
#  "n't",
#  'get',
#  'out',
#  'of',
#  'the',
#  'blocks',
#  'quick',
#  'enough',
#  'at',
#  'the',
#  'start',
#  'of',
#  'the',
#  'second',
#  'half',
#  'it',
#  'felt',
#  'like',
#  'arsenal',
#  'were',
#  'the',
#  'more',
#  'proactive',
#  'until',
#  'they',
#  'scored',
#  'their',
#  'goal',
#  'i',
#  'felt',
#  'we',
#  'could',
#  'get',
#  'a',
#  'goal',
#  'at',
#  'the',
#  'end',
#  'and',
#  'we',
#  'sent',
#  'men',
#  'forward',
#  'i',
#  "'ve",
#  'been',
#  'in',
#  'that',
#  'situation',
#  'as',
#  'a',
#  'player',
#  'when',
#  'you',
#  'come',
#  'off',
#  'and',
#  'think',
#  'you',
#  'could',
#  "'ve",
#  'got',
#  'more',
#  'out',
#  'of',
#  'a',
#  'game',
#  'but',
#  'we',
#  "'ll",
#  'learn',
#  'from',
#  'this',
#  'arsenal',
#  'manager',
#  'unai',
#  'emery',
#  'i',
#  'want',
#  'more',
#  'more',
#  'in',
#  'the',
#  'result',
#  'and',
#  'in',
#  'the',
#  'performance',
#  'but',
#  'we',
#  'are',
#  'progressing',
#  'we',
#  'were',
#  'competitive',
#  'but',
#  'we',
#  'can',
#  'do',
#  'better',
#  'we',
#  'can',
#  'control',
#  'moments',
#  'with',
#  'the',
#  'ball',
#  'better',
#  'and',
#  'take',
#  'more',
#  'chances',
#  'in',
#  'the',
#  'box',
#  'we',
#  'have',
#  'young',
#  'players',
#  'who',
#  'can',
#  'take',
#  'confidence',
#  'bukayo',
#  'saka',
#  'is',
#  'progressing',
#  'well',
#  'but',
#  'we',
#  'need',
#  'other',
#  'players',
#  'too',
#  'this',
#  'is',
#  'not',
#  'the',
#  'best',
#  'in',
#  'terms',
#  'of',
#  'points',
#  'but',
#  'one',
#  'point',
#  'can',
#  'be',
#  'good',
#  'if',
#  'we',
#  'win',
#  'next',
#  'sunday',
#  'against',
#  'bournemouth']

# %%
# %%time
processor.vocabulary_length(text_type='article')
# Out:
# Building vocabulary for article
# CPU times: user 2min 14s, sys: 200 ms, total: 2min 14s
# Wall time: 2min 15s
# 15245

# %%
# %%time
processor.vocabulary_length(text_type='article')
# Out:
# Building vocabulary for article
# CPU times: user 2min 19s, sys: 1.63 s, total: 2min 21s
# Wall time: 2min 21s
# 15298

# %%
len(processor.words['article'])
# Out:
# 15245

# %%
# %%time
processor.vocabulary_length(text_type='events')
# Out:
# Building vocabulary for events
# CPU times: user 9min 6s, sys: 48.3 s, total: 9min 54s
# Wall time: 9min 54s
# 8084

# %%
vocab_dict = processor.vocabulary_dict

# %%
vocab_dict['article']
# Out:
# {'dismayed',
#  'woodworking',
#  'vargas',
#  'rested',
#  'moralez',
#  'conclude',
#  'bandaged',
#  'contaban',
#  'outpouring',
#  'ari',
#  'responders',
#  'stopped',
#  'kimmich',
#  'acting',
#  'perry',
#  'help',
#  'a.m.',
#  'arsenal',
#  'cctv',
#  'shallow',
#  'admission',
#  'understated',
#  'unused',
#  'pinpoint',
#  'miguel',
#  'gleaned',
#  'styled',
#  'posession',
#  'peña',
#  'unexpectedly',
#  'middling',
#  'rotate',
#  'galvez',
#  'stereotyped',
#  'necks',
#  'yours',
#  'gattuso',
#  'veliz',
#  'blossom',
#  'smaller',
#  'armchair',
#  'away',
#  'mahrez',
#  'wober',
#  'soriano',
#  'unsurprisingly',
#  'wreaking',
#  'mortified',
#  'atmosphere',
#  'incredulous',
#  'fo',
#  'aleksey',
#  'usavbih',
#  'gatt',
#  'prompt',
#  'jomo',
#  'energized',
#  'ibe',
#  'borderline',
#  'humidity',
#  'cylinders',
#  '👶',
#  'lob',
#  'markedly',
#  'instinctive',
#  'optimistic',
#  'dello',
#  'availability',
#  'semi-',
#  'unattended',
#  'grasp',
#  'boli',
#  'rene',
#  'privat',
#  'lives',
#  'colvtor',
#  'ruggedly',
#  'onslaught',
#  'tyler',
#  'myriad',
#  'kainz',
#  'wc',
#  'chest',
#  '👑',
#  'busy',
#  'armeros',
#  'identities',
#  'bc',
#  'english',
#  'claws',
#  'timothy',
#  'amusing',
#  'takuma',
#  'usavpur',
#  'incensed',
#  'stakeholder',
#  'derailed',
#  'manneh',
#  'motivators',
#  'iduna',
#  'congrats',
#  'bolanos',
#  'nicolás',
#  'eamon',
#  'riding',
#  'cutback',
#  'cabbages',
#  'cupped',
#  'unlikely',
#  'albadawi',
#  'jakub',
#  'call',
#  'glitzy',
#  'brands',
#  'versatile',
#  'markel',
#  'curtailed',
#  'castagne',
#  'wcqs',
#  'backing',
#  'ebb',
#  'changes',
#  'azteca',
#  'munich',
#  'faze',
#  'jacob',
#  'easing',
#  'bend',
#  'cool',
#  'claw',
#  'jinxed',
#  'jostled',
#  'prior',
#  'porvhou',
#  'brillant',
#  'greater',
#  'lamah',
#  'falls',
#  'road',
#  'pimentel',
#  'jan.',
#  'academies',
#  'caffa',
#  'damion',
#  'cement',
#  'allay',
#  'bifurcated',
#  '😎',
#  'darmian',
#  'activated',
#  'seeming',
#  'konsa',
#  'ratchets',
#  'hotspur',
#  'padraig',
#  'rmc',
#  'patience',
#  'toth',
#  'td',
#  'boosting',
#  'vaugh',
#  'teamsheets',
#  'uanl',
#  'equalised',
#  'karol',
#  'malcolm',
#  'usavpar',
#  'barged',
#  'warming',
#  'dialogue',
#  'bends',
#  'eh',
#  'peterson',
#  'deuce',
#  'possibly',
#  'niko',
#  'heber',
#  'scott',
#  'shellacked',
#  'almighty',
#  'quique',
#  'sheets',
#  'cheated',
#  'nasty',
#  'juventus',
#  'threatened',
#  'marshall',
#  'clinical',
#  'venomous',
#  'acclaimed',
#  'retaliated',
#  'darwin',
#  'superpowers',
#  'careca',
#  'raffaele',
#  'bonaventura',
#  'cinema',
#  'angella',
#  'watching',
#  'mx',
#  'atletisevillafc',
#  'convinced',
#  'marchetti',
#  'flood',
#  'crossed',
#  'plaudits',
#  'electricity',
#  'providing',
#  'rbnyvlafc',
#  'precision',
#  'bursting',
#  'beaters',
#  'understandably',
#  'deferred',
#  'kidding',
#  'eking',
#  'dented',
#  '📐',
#  'pelted',
#  'grenade',
#  'scripted',
#  'ditto',
#  'accelerated',
#  'proposition',
#  'jankto',
#  'strife',
#  'mostly',
#  'reviews',
#  'lift',
#  'swung',
#  'standpoint',
#  'ringside',
#  'preoccupied',
#  'lossl',
#  'finish',
#  'slipping',
#  'object',
#  'vice',
#  'guaje',
#  'town',
#  'submarine',
#  'racing',
#  'overwhelming',
#  'primed',
#  'whacks',
#  'drives',
#  'fabi',
#  'interruption',
#  'talking',
#  'avenged',
#  'disturbing',
#  'withstand',
#  'being',
#  'alas',
#  'dioga',
#  'sleeping',
#  'wout',
#  'nottingham',
#  'regarded',
#  'tri',
#  'wingbacks',
#  'improvement',
#  'angry',
#  'visitante',
#  'tell',
#  'tarbell',
#  'spoil',
#  'display',
#  'initiate',
#  'svantesson',
#  'rosas',
#  'captained',
#  'edersen',
#  'foyth',
#  'lance',
#  'thereau',
#  'plies',
#  'huesca',
#  'including',
#  'areas',
#  'securing',
#  'circuitous',
#  'kieran',
#  'braut',
#  'jermaine',
#  'question',
#  'cesare',
#  'stubborn',
#  'est',
#  'jaume',
#  'zealand',
#  'goalline',
#  'pierrot',
#  'tau',
#  'flemmings',
#  'nonsense',
#  'sizing',
#  'existent',
#  'faycal',
#  'rodrigues',
#  'force',
#  'stats',
#  'prevent',
#  'holds',
#  'paraguayan',
#  'marvin',
#  'kleindienst',
#  'eagles',
#  'recycled',
#  'kadeisha',
#  'blood',
#  'dany',
#  'replays',
#  'summariser',
#  'shkelzen',
#  'rank',
#  'mepham',
#  'paparatto',
#  'lagerwey',
#  'forsberg',
#  'affairs',
#  'tribbett',
#  'augustin',
#  'sprinkled',
#  'queretaro',
#  'appointment',
#  'hallmark',
#  'almeyda',
#  'cindy',
#  'pay',
#  'amiens',
#  'fearsome',
#  'porvsj',
#  'rzatkowski',
#  'mojica',
#  'del',
#  'galindo',
#  'arnaut',
#  'ago',
#  'converting',
#  'beautiful',
#  'justify',
#  'justiana',
#  'usl',
#  'valladolid',
#  'prefer',
#  'sank',
#  'earliest',
#  'fernando',
#  'via',
#  'channels',
#  'someone',
#  'insurance',
#  'cranks',
#  'slate',
#  'pinho',
#  'tightness',
#  'ballew',
#  'omissions',
#  'glad',
#  'marquinhos',
#  'peabo',
#  'advertising',
#  'witnessing',
#  'tutt',
#  'tukwila',
#  'cucurella',
#  'relief',
#  'quiet',
#  'fumbled',
#  'matarrita',
#  'asamoah',
#  'hadji',
#  'debuchy',
#  'home',
#  'unblemished',
#  '🌑',
#  'ignore',
#  'trevor',
#  'productive',
#  'equipped',
#  'enes',
#  'cinvny',
#  'positively',
#  'field',
#  '¦',
#  'troublemakers',
#  'fit',
#  'erase',
#  'mac',
#  'franchi',
#  'primary',
#  'ligament',
#  'formidable',
#  'mouth',
#  'keown',
#  'worried',
#  'plan',
#  'gardner',
#  'annual',
#  'describe',
#  'washed',
#  'unstinting',
#  'plunged',
#  'laughing',
#  'wrinkles',
#  'frustrated',
#  'journalists',
#  'settles',
#  'captaincy',
#  'houston',
#  'improved',
#  'dilly',
#  'resuming',
#  'application',
#  'bones',
#  'dirty',
#  'tomiyasu',
#  'forever',
#  'scalia',
#  'fluently',
#  'triggering',
#  'radja',
#  'odegaard',
#  'anoeta',
#  'confrontation',
#  'flawed',
#  'cold',
#  'pen',
#  'collective',
#  'pérez',
#  'dabritz',
#  'basten',
#  'hendricks',
#  'sandri',
#  'poor',
#  'jesús',
#  'seavnyc',
#  'discovered',
#  'mobile',
#  'tae',
#  'impossible',
#  'tripping',
#  'rounds',
#  'risky',
#  'longatsff',
#  'venezuelan',
#  'smug',
#  'shoo',
#  'utd',
#  'guarded',
#  'zadorsky',
#  'criscito',
#  'fierce',
#  'fortuitously',
#  'patiently',
#  'ramadan',
#  'nemanja',
#  'revealing',
#  'mr',
#  'worldies',
#  'moore',
#  'bakayoko',
#  'touted',
#  'spare',
#  'mighty',
#  'salas',
#  'tavares',
#  'band',
#  'unqualified',
#  'henrikh',
#  'replacement',
#  'jasper',
#  'apace',
#  'won',
#  'settle',
#  'hasselbaink',
#  'stall',
#  'cafeteros',
#  'hospital',
#  'sept.',
#  'incisive',
#  'teams',
#  'extraordinary',
#  'hoover',
#  'uncertainty',
#  'spongy',
#  'muscles',
#  'henrichs',
#  'forgot',
#  'relied',
#  'flagging',
#  'strangely',
#  'ruhaak',
#  'matt',
#  'continents',
#  'hubner',
#  'swivelled',
#  'lead',
#  'tame',
#  'georginio',
#  'aubrey',
#  'pays',
#  'spirit',
#  'apoel',
#  'guided',
#  'reigning',
#  'duel',
#  'vociferous',
#  'japanese',
#  'notionally',
#  'motta',
#  'battery',
#  'physically',
#  'hyper',
#  'wife',
#  'badeji',
#  'angles',
#  'spot',
#  'lacroix',
#  'twinkle',
#  'hunt',
#  'deadlocked',
#  'served',
#  'jul.',
#  'pertinently',
#  'a)watford',
#  'yank',
#  'youngsters',
#  'lineup',
#  'cedrick',
#  'terrific',
#  'romagnoli',
#  'style',
#  'kaoru',
#  'wales',
#  'leave',
#  'chilwell',
#  'dangling',
#  'unmoved',
#  'harsh',
#  'bitterly',
#  'invincibility',
#  'holland',
#  'bo',
#  'reo',
#  'relying',
#  'masked',
#  '😅',
#  'increased',
#  'ledbetter',
#  'badge',
#  'unsatisfactory',
#  'pleas',
#  'assuring',
#  'pale',
#  'overturning',
#  'ease',
#  'mental',
#  'fosun',
#  'grazing',
#  'volesky',
#  'veljko',
#  'howitzer',
#  'sunday',
#  'attendances',
#  'finishers',
#  'tinker',
#  'nearly',
#  'marcus',
#  'negatives',
#  'fran',
#  'onward',
#  'nycvlafc',
#  'muggy',
#  'staying',
#  'guram',
#  'rodolph',
#  "coudn't",
#  'unfolded',
#  'niang',
#  'intensify',
#  'hughes',
#  'melara',
#  'toronto',
#  'kickers',
#  'sesay',
#  'mccabe',
#  'expensively',
#  'david',
#  'pa',
#  'badou',
#  'howling',
#  'receding',
#  'air',
#  'transported',
#  'ranted',
#  'rajko',
#  'lash',
#  'dusseldorf',
#  'contesting',
#  'route',
#  'salamanca',
#  'famed',
#  '€',
#  'minvla',
#  'survivors',
#  'creation',
#  'roversio',
#  'isaac',
#  'valon',
#  'providers',
#  'hips',
#  'academy',
#  'gervinho',
#  'equestrian',
#  'banger',
#  'inducted',
#  'concussion',
#  'fati',
#  'color',
#  'bonilla',
#  'determining',
#  'naby',
#  'parrying',
#  'valuable',
#  'mass',
#  'coaching',
#  'dario',
#  'skcvne',
#  'swarmed',
#  'into',
#  'pumped',
#  'armada',
#  'oversubscribed',
#  'seavlafc',
#  'impacts',
#  'weighing',
#  'g.',
#  'gazidis',
#  'pereyra',
#  'salvaging',
#  'germans',
#  'owing',
#  'drinkwater',
#  'shellshocked',
#  'sullivan',
#  'matthias',
#  'heeded',
#  'tenser',
#  'bookend',
#  'demanded',
#  'seavrsl',
#  'an',
#  'improbably',
#  'aston',
#  'except',
#  'kovar',
#  'craved',
#  'drags',
#  'became',
#  'cruz',
#  'apex',
#  'odoi',
#  'annals',
#  'laterally',
#  'knew',
#  'rapids',
#  'hasan',
#  'basuljevic',
#  'h)everton',
#  'squarely',
#  'franco',
#  'firstly',
#  'certain',
#  'moreno',
#  'havre',
#  'perennial',
#  'quicksilver',
#  'things',
#  'clutch',
#  'ty',
#  'sokratis',
#  'culture',
#  'dragón',
#  'sharks',
#  'stadiums',
#  'skriniar',
#  'converging',
#  'decisiveness',
#  'joking',
#  'matjasic',
#  'outpass',
#  'skcvchi',
#  'stanislas',
#  'missiles',
#  'quake',
#  'survivor',
#  'yamil',
#  'pantera',
#  'utilityman',
#  'midweek',
#  'binks',
#  'fortunately',
#  'honesty',
#  'threadbare',
#  'rosendo',
#  'bolasie',
#  'grafted',
#  'moral',
#  'frustrate',
#  'maturity',
#  'coughed',
#  'input',
#  'item',
#  'poured',
#  'reserves',
#  'preventable',
#  'footrace',
#  'move',
#  'tact',
#  'jar',
#  'chirinos',
#  'absorb',
#  'braces',
#  'jairo',
#  'casner',
#  'worm',
#  'elseid',
#  'enticed',
#  'holness',
#  'laryea',
#  'declined',
#  'garitano',
#  'orsolini',
#  'cm',
#  'caldwell',
#  'nil',
#  'wanyama',
#  'counter',
#  'miranchuk',
#  'stun',
#  'reasons',
#  'favorites',
#  'headquarters',
#  'urinated',
#  'eyelid',
#  'appreciated',
#  'boateng',
#  'forty',
#  'inspiring',
#  'leitch',
#  'lundqvist',
#  'collarbone',
#  'fer',
#  'dropping',
#  'touch',
#  'of',
#  'forge',
#  'results',
#  'winston',
#  'hall',
#  'ghanaian',
#  'whereas',
#  'dash',
#  'potters',
#  'plain',
#  'dhillon',
#  'riley',
#  'blues',
#  'perparim',
#  'sandwiching',
#  'fervour',
#  'contrast',
#  'swashbuckling',
#  'sure',
#  'confines',
#  'eusebio',
#  'directness',
#  'lappalainen',
#  'goes',
#  'smolders',
#  'national',
#  'swoon',
#  'luthe',
#  'centerback',
#  'quioto',
#  'torvlafc',
#  'stifle',
#  'berat',
#  'steeven',
#  'rasmussen',
#  'arcing',
#  'sead',
#  'reserving',
#  'cucho',
#  'decisions',
#  'uninspiring',
#  'belgium',
#  'limit',
#  'valiant',
#  'dele',
#  'sum',
#  'purely',
#  'front',
#  'books',
#  'latching',
#  'effervescent',
#  'replaces',
#  'foot',
#  'quest',
#  'at',
#  'teibert',
#  'islam',
#  'stunned',
#  'guillen',
#  'medie',
#  'constitutes',
#  'invincibles',
#  'wriggled',
#  'returning',
#  'cheekily',
#  'ramy',
#  'amarikwa',
#  'michy',
#  'shriver',
#  'matched',
#  'leadership',
#  'nevis',
#  'hiljemark',
#  'twisted',
#  'cristiano',
#  'unguarded',
#  'imo',
#  '📕',
#  'puch',
#  'uncharted',
#  'frequently',
#  'artful',
#  'innocuous',
#  'echelons',
#  'dehydration',
#  'hungry',
#  'msg',
#  'crouch',
#  'nuri',
#  'beings',
#  'feat',
#  'punches',
#  'salih',
#  'educated',
#  'ginger',
#  'huth',
#  'kramer',
#  'classic',
#  'heightened',
#  "'d",
#  'defrel',
#  'tallies',
#  'alex',
#  'soothed',
#  'labrocca',
#  'anybody',
#  'perceived',
#  'scoreboard',
#  'spurned',
#  'davies',
#  'celso',
#  'navarro',
#  'mcclain',
#  'ugly',
#  'nightfall',
#  'ciaran',
#  'representative',
#  'cutrone',
#  'honest',
#  'health',
#  'ticking',
#  'science',
#  'australian',
#  'directions',
#  'original',
#  'weakly',
#  'hampering',
#  'alfie',
#  'dzemaili',
#  'seamus',
#  'westcott',
#  'learner',
#  'grizzled',
#  'penalty',
#  'asked',
#  'gorgeously',
#  'manoeuvre',
#  'bullying',
#  'tipping',
#  '💜',
#  'rouges',
#  'avalos',
#  'marching',
#  'muto',
#  'poked',
#  'avail',
#  'stationary',
#  'coped',
#  'snowy',
#  'bothroyd',
#  'dubbed',
#  'personality',
#  'overtook',
#  'bramall',
#  'dalvpor',
#  'coughing',
#  'andalusian',
#  'toss',
#  'familiar',
#  'wahl',
#  'languishing',
#  'karma',
#  'palms',
#  'chivtor',
#  'deepening',
#  'menacing',
#  'neal',
#  'hardworking',
#  'grab',
#  'argument',
#  'elfath',
#  'stoeger',
#  'solid',
#  'thuram',
#  'microcosm',
#  'snaffle',
#  'hassenhuttl',
#  'ornstil',
#  'identified',
#  'cards',
#  'rumours',
#  'nevin',
#  'energizer',
#  'earth',
#  'insulting',
#  'setting',
#  'marinović',
#  'remiro',
#  'policy',
#  'implosion',
#  'kinnear',
#  'untidy',
#  'beresford',
#  'unflustered',
#  'replete',
#  'deulofeu',
#  'slap',
#  'rutherford',
#  'ceramica',
#  'searched',
#  'internationals',
#  'neck',
#  'mallo',
#  'intercepted',
#  'pitting',
#  'thinking',
#  'splashed',
#  'endure',
#  'boosted',
#  'integral',
#  'fingers',
#  'souls',
#  'improvised',
#  'painful',
#  'selected',
#  'advances',
#  'gomes',
#  'chivmtl',
#  'stated',
#  'nketiah',
#  'palacio',
#  'wrestle',
#  'stories',
#  'mistiming',
#  'takeaways',
#  'groans',
#  'vidéo',
#  'malone',
#  'tigerish',
#  'gameday',
#  'deservedly',
#  'sports',
#  'unfancied',
#  'evaporated',
#  'alvbage',
#  'narrowing',
#  'successors',
#  'propensity',
#  'hume',
#  'les',
#  'fredy',
#  'despatching',
#  'restructuring',
#  ...}

# %%
vocab_dict['events']
# Out:
# {'alessio',
#  'nahuel',
#  'sjoberg',
#  'antonelli',
#  'pyatov',
#  'hunt',
#  'hulk',
#  'thompson',
#  'hiljemark',
#  'farrell',
#  'ibrahima',
#  'high',
#  'calleri',
#  'alston',
#  'off!second',
#  'aanholt',
#  'eustáquio',
#  'sylla',
#  'dussenne',
#  'solignac',
#  'ionita',
#  'luigi',
#  'wheeler',
#  'card!didier',
#  'bonfim',
#  'wiel',
#  'plavsic',
#  'chimy',
#  'rouwen',
#  'card!emre',
#  'dalbert',
#  'santiago',
#  'kwadwo',
#  'ahmetovic',
#  'lobotka',
#  'collado',
#  'revoredo',
#  'khasanov',
#  'max',
#  'melero',
#  'hugues',
#  'gonzález',
#  'hoffenheim',
#  'panama',
#  'nugent',
#  'santamaría',
#  'lees',
#  'card!andrea',
#  'fleming',
#  'gaitán',
#  'header',
#  'larrea',
#  'politano',
#  'toulouse',
#  'baumgartl',
#  'karaman',
#  'stryger',
#  'hurtado',
#  'francisco',
#  'manchester',
#  'radoja',
#  'shelina',
#  'skrzybski',
#  'ounas',
#  'kruse',
#  'kunga',
#  'duk',
#  'wal',
#  'cermeño',
#  'moges',
#  'münchen',
#  'goodridge',
#  'chávez',
#  'reinildo',
#  'dalot',
#  'bordeaux',
#  'eriq',
#  'taison',
#  'edin',
#  'ilija',
#  'shaffelburg',
#  'aljaz',
#  'tobi',
#  'ndombele',
#  'vid',
#  'mounie',
#  'solomon',
#  'ballo',
#  'magnanelli',
#  'javier',
#  'deybi',
#  'podence',
#  'illarramendi',
#  'riccardi',
#  'sergiy',
#  'ugalde',
#  'laurini',
#  'vfl',
#  'kuzain',
#  'eudes',
#  'okello',
#  'winslow',
#  'puscas',
#  'koch',
#  'musonda',
#  'kaylen',
#  'bakkali',
#  'alihidivoc',
#  'trézéguet',
#  'shane',
#  'geiger',
#  'gumbau',
#  'beltrame',
#  'pinamonti',
#  'ford',
#  'bautista',
#  'perrin',
#  'corona',
#  'red',
#  'martín',
#  'lekue',
#  'héber',
#  'tigres',
#  'atuahene',
#  'ulloa',
#  'turnley',
#  'matis',
#  'samuelsson',
#  'bahoken',
#  'portillo',
#  'ikechi',
#  'card!son',
#  'rene',
#  'moubandje',
#  "m'baye",
#  'barco',
#  'wade',
#  'fsv',
#  'cox',
#  'hemed',
#  'khazri',
#  'rodrigo',
#  'cavaleiro',
#  'bonucci',
#  'álvarez',
#  'willems',
#  'ghiglione',
#  'kurzawa',
#  'cherki',
#  'zealand',
#  'isco',
#  'moffat',
#  'geynrikh',
#  'tyrone',
#  'abate',
#  'bismarck',
#  'hlavaty',
#  'kownacki',
#  'stajduhar',
#  'caraglio',
#  'balanta',
#  'raffaele',
#  'bigas',
#  'nkoulou',
#  'ghislain',
#  'morgan',
#  'card!maxime',
#  'field',
#  'cabit',
#  'bahner',
#  'cunningham',
#  'stojanovic',
#  'ngakia',
#  'kamdem',
#  'keitel',
#  'darryl',
#  'strikers',
#  'ezequiel',
#  'farias',
#  'ayhan',
#  'clemons',
#  'mike',
#  'smith',
#  'larín',
#  'jhonder',
#  'grzegorz',
#  'tonali',
#  'takefusa',
#  'gastón',
#  'requejo',
#  'del',
#  'zhemaletdinov',
#  'kaminski',
#  'erickson',
#  'rennes',
#  'gebre',
#  'cancelo',
#  'chancellor',
#  'kantari',
#  'lejeune',
#  'corboz',
#  'gibran',
#  'muslija',
#  'down',
#  'neumann',
#  'opoku',
#  'berenguer',
#  'vines',
#  'cásseres',
#  'ripart',
#  'anibaba',
#  'salamon',
#  'alan',
#  'carolina',
#  'espinosa',
#  'ferreiro',
#  'pat',
#  'alessandro',
#  'matz',
#  'mac',
#  'lade',
#  'kjartan',
#  'horst',
#  'besic',
#  'alvin',
#  'orsolini',
#  'mamadou',
#  'wilshere',
#  'santi',
#  'no',
#  'blake',
#  'kennedy',
#  'emeterio',
#  'giro',
#  'kayne',
#  'state',
#  'sean',
#  'saprissa',
#  'pizzi',
#  'card!kepa',
#  'vladislav',
#  '3(4',
#  'sjöberg',
#  'veliz',
#  'jair',
#  'darmian',
#  'guzman',
#  'ales',
#  'domínguez',
#  'iturbe',
#  'daneil',
#  'surridge',
#  'mooy',
#  'zinedine',
#  'lille',
#  'choupo',
#  'duffy',
#  'drogba',
#  'erwin',
#  'salisu',
#  'raspadori',
#  'coruña',
#  'dick',
#  'eintracht',
#  'yefferson',
#  'thomas',
#  'makengo',
#  'mustivar',
#  'luka',
#  'corchia',
#  'vezo',
#  'saintil',
#  'olkowski',
#  'bremen',
#  'seiler',
#  'ellis',
#  'izquierdo',
#  'yeltsin',
#  'däbritz',
#  'dominic',
#  'bekker',
#  'matej',
#  'goller',
#  'vinícius',
#  'matias',
#  'arquímedes',
#  'lobanov',
#  'armas',
#  'oihan',
#  'elmohamady',
#  'nahki',
#  'city',
#  'diabaté',
#  'chris',
#  'vlad',
#  'mohammed',
#  'jastrzembski',
#  'marchisio',
#  'card!tiemoué',
#  'jeb',
#  'vesga',
#  'card!jesús',
#  'budimir',
#  'nkoudou',
#  'bajic',
#  'arter',
#  'kessler',
#  'delort',
#  'barnes',
#  'savic',
#  'mejia',
#  'healey',
#  'millico',
#  'salloi',
#  'stieber',
#  'kjaer',
#  'vásquez',
#  'guadalajara',
#  'issa',
#  'modric',
#  'woo',
#  'card!philip',
#  'ivi',
#  'dane',
#  'omeruo',
#  'taintor',
#  'durmisi',
#  'alexis',
#  'richie',
#  'card!denis',
#  'efthymios',
#  'younès',
#  'quaner',
#  'graovac',
#  'capoue',
#  'fredericks',
#  'stephanie',
#  'lachman',
#  'kwon',
#  'ighalo',
#  'skhiri',
#  'altidore',
#  'kilman',
#  'acheampong',
#  '1(5',
#  'wilkinson',
#  'napo',
#  'magaña',
#  'price',
#  'sturaro',
#  'rasmussen',
#  'boden',
#  'aldo',
#  'kent',
#  'coda',
#  'toia',
#  'albrighton',
#  'torino',
#  'burke',
#  'atsu',
#  'hughes',
#  'clayton',
#  'magnetti',
#  'dayron',
#  'rakitic',
#  'souquet',
#  'saponara',
#  'sito',
#  'sacramento',
#  'alzate',
#  'magee',
#  'murru',
#  '3(5',
#  'attinella',
#  'kwame',
#  'piette',
#  'tuiloma',
#  'birnbaum',
#  'locadia',
#  'bowen',
#  'bad',
#  'muhamed',
#  'pucciarelli',
#  'reguilón',
#  'raejae',
#  'aye',
#  'wilfried',
#  'fort',
#  'patterson',
#  'stojkov',
#  '2(2',
#  'nicola',
#  'unido',
#  'castro',
#  'faitout',
#  'tawatha',
#  'zimmermann',
#  'atal',
#  'chilwell',
#  'ingvartsen',
#  'lubahn',
#  'gunnarsson',
#  'algarañaz',
#  'villa',
#  'westberg',
#  'shukurov',
#  'card!wes',
#  'idah',
#  'pazzini',
#  'cole',
#  'fiorentina',
#  'card!luis',
#  'miletic',
#  'ludovic',
#  'enis',
#  'headed',
#  'malik',
#  'oviedo',
#  'heaton',
#  'glad',
#  'marseille',
#  'oekel',
#  'renard',
#  'brignoli',
#  'darragh',
#  'jans',
#  'pépé',
#  'cyril',
#  'payne',
#  'auro',
#  'logan',
#  'colman',
#  'card!ivan',
#  'bladimir',
#  'sardar',
#  'zardes',
#  'salah',
#  'maynor',
#  'musacchio',
#  'szetela',
#  'yann',
#  'ream',
#  'karsdorp',
#  'aurelien',
#  'derrick',
#  'rafal',
#  'curcio',
#  'michy',
#  'card!eric',
#  'mor',
#  'hooi',
#  'card!john',
#  'tommy',
#  'mees',
#  'card!pierre',
#  'tapia',
#  'torreira',
#  'buescher',
#  'larentowicz',
#  'kylian',
#  'arbilla',
#  'caracciolo',
#  'jacori',
#  'nagy',
#  'billy',
#  'la',
#  'raldes',
#  'roldan',
#  'musa',
#  'benavente',
#  'card!benjamin',
#  'duke',
#  'desiree',
#  'delph',
#  'toño',
#  'vietto',
#  'wiedeman',
#  'parra',
#  'dorren',
#  'ualefi',
#  'jakovic',
#  'kenny',
#  'seri',
#  'malachi',
#  'piszczek',
#  'campaña',
#  'rusnák',
#  'atalanta',
#  '0',
#  'hummels',
#  'card!vicente',
#  'yards',
#  'lainez',
#  'card!nicolás',
#  'wuilito',
#  'bruin',
#  'hélder',
#  'vavro',
#  'card!xherdan',
#  'sanson',
#  'daniele',
#  'penedo',
#  'card!ahmed',
#  'baumgartner',
#  'darlington',
#  'brosinski',
#  'johannesson',
#  'richard',
#  'sokhibov',
#  'valère',
#  'parker',
#  'pastore',
#  'murphy',
#  'brault',
#  'radovan',
#  'echeverri',
#  'bauer',
#  'fire',
#  'seyi',
#  'didavi',
#  'blin',
#  'ezekiel',
#  'servando',
#  'matthieu',
#  'sarr',
#  'lovren',
#  'sabiri',
#  'joaquin',
#  'maguire',
#  'ivey',
#  'damian',
#  'marney',
#  'diego',
#  'willock',
#  'jóhannsson',
#  'munas',
#  'epps',
#  'slattery',
#  'jansson',
#  'braithwaite',
#  'svanberg',
#  'kramer',
#  'cafú',
#  'bessa',
#  'asllani',
#  'silvan',
#  'knoche',
#  'eloundou',
#  'justen',
#  'bou',
#  'tyrese',
#  'kaoru',
#  'lass',
#  'iacoponi',
#  'ramsdale',
#  'card!christian',
#  'brownhill',
#  'bizama',
#  'mcinerney',
#  'dostonbek',
#  'takehiro',
#  'kratz',
#  'rashica',
#  'benassi',
#  'nordfeldt',
#  'gaspar',
#  'card!kadeem',
#  'leander',
#  'matip',
#  'giulio',
#  'lambese',
#  'britos',
#  'don',
#  'miramón',
#  'halilovic',
#  'sehrou',
#  'chaney',
#  'martinelli',
#  'boli',
#  'robinho',
#  'frater',
#  'pina',
#  'mena',
#  'kitchen',
#  'almirón',
#  'zenteno',
#  'jason',
#  'addles',
#  'mayron',
#  'ruben',
#  'jallet',
#  'peru',
#  'norwich',
#  'montano',
#  'wondolowski',
#  'valle',
#  'lodeiro',
#  'saric',
#  'nani',
#  'vadim',
#  'weiser',
#  'davis',
#  'angella',
#  'balogun',
#  'calvin',
#  'alberth',
#  'ximo',
#  'kovar',
#  'chaplow',
#  'abdullayev',
#  'card!matty',
#  'harrison',
#  'freese',
#  'greenspan',
#  'mcgoldrick',
#  'elijah',
#  'weah',
#  'card!adlène',
#  'ovalle',
#  'capuano',
#  'cerri',
#  'colombia',
#  'grant',
#  'ødegaard',
#  'kerem',
#  'murofushi',
#  'chauvet',
#  'saad',
#  'barton',
#  'quini',
#  'embarba',
#  'statie',
#  'carrillo',
#  'jantschke',
#  'terence',
#  'azogue',
#  'flanagan',
#  'gee',
#  'bruce',
#  'azofeifa',
#  'leonie',
#  'arfield',
#  'arnor',
#  'fierro',
#  'bennasser',
#  'butterfield',
#  'rossettini',
#  'raúl',
#  'doukouré',
#  'moyano',
#  'hamid',
#  'griffiths',
#  'kosta',
#  'ready',
#  'pirmin',
#  'samassékou',
#  'depaoli',
#  'joan',
#  'zohore',
#  'mix',
#  'dimitrios',
#  'souprayen',
#  'salih',
#  'neven',
#  'nkada',
#  'manny',
#  'giménez',
#  'sabelli',
#  'joris',
#  'shakhov',
#  'remo',
#  'card!kevin',
#  'norris',
#  'sal',
#  'barrera',
#  'lage',
#  'than',
#  'card!marko',
#  'shelton',
#  'confirmed',
#  'hamilton',
#  'celso',
#  'adrià',
#  'mack',
#  'card!david',
#  'sejad',
#  'opportunity',
#  'mceleney',
#  'card!sam',
#  'winchester',
#  'ilkay',
#  'caleta',
#  'berisha',
#  'birger',
#  'brasanac',
#  'minnesota',
#  'bender',
#  'navas',
#  'cecchini',
#  'izquierdóz',
#  'card!ben',
#  'lucky',
#  'oliver',
#  'riquelme',
#  'ngonda',
#  'mago',
#  'fabricio',
#  'saramutin',
#  'organista',
#  'naughton',
#  'whitehead',
#  'marsh',
#  'sandoval',
#  'stanislas',
#  'kayal',
#  'valentín',
#  'eibar',
#  'alejandro',
#  'marcelin',
#  'omer',
#  'aday',
#  'card!etienne',
#  'sener',
#  'jacob',
#  'pino',
#  'sörensen',
#  'slater',
#  'konopka',
#  'michaud',
#  'arabe',
#  'costel',
#  'judson',
#  'kaderábek',
#  'emery',
#  'cádiz',
#  'przybylko',
#  'vokes',
#  'card!max',
#  'balic',
#  'lo',
#  'herelle',
#  'mollet',
#  'posch',
#  'samudio',
#  'chadrac',
#  'veltman',
#  'olabiyi',
#  'jarchinio',
#  'fuente',
#  'guédioura',
#  'orozco',
#  'ruibal',
#  'nicki',
#  'luz',
#  'card!joey',
#  'ducksch',
#  'husbauer',
#  'hjulsager',
#  'dragan',
#  'kebano',
#  'woodbine',
#  'stambouli',
#  'eddy',
#  'el',
#  'jakob',
#  'ampadu',
#  'vrij',
#  '07',
#  'najem',
#  'boubacar',
#  'badstuber',
#  'chukwueze',
#  'odey',
#  'courtois',
#  'card!duncan',
#  'wijnaldum',
#  'lemar',
#  'pavel',
#  'chancel',
#  'iemmello',
#  'this',
#  'ichazo',
#  'card!zlatan',
#  'behringer',
#  'hegazi',
#  'sacha',
#  'kouamé',
#  'pashaev',
#  'porfirio',
#  'prödl',
#  'mukhammadiev',
#  'holgate',
#  'andrae',
#  'düsseldorf',
#  'berry',
#  'folivi',
#  'contout',
#  'ludwig',
#  'jonathas',
#  'kasey',
#  'card!marc',
#  'ekdal',
#  'alcenat',
#  'romagnoli',
#  'hoffmann',
#  'rhett',
#  'card!allan',
#  'tito',
#  'cortés',
#  'rooney',
#  'jamie',
#  'jimmy',
#  'ayarza',
#  'lovro',
#  'tecl',
#  'meredith',
#  'mls',
#  'onuachu',
#  'lamah',
#  'kristensen',
#  'pen',
#  'marcão',
#  'lassiter',
#  'elez',
#  'odisnel',
#  'catherine',
#  'diprima',
#  'michail',
#  'ferland',
#  'maycon',
#  'kossounou',
#  'griffin',
#  'magallán',
#  'bartels',
#  'gil',
#  'kolar',
#  'sambueza',
#  'brangman',
#  'warming',
#  'jamiel',
#  'atsem',
#  'mansally',
#  'abdoulie',
#  'schelotto',
#  'berge',
#  'perone',
#  'fortuna',
#  'sixto',
#  'card!victor',
#  'amat',
#  'kléber',
#  'miles',
#  'card!jürgen',
#  'rick',
#  'wit',
#  'nilo',
#  'card!chicharito',
#  'partida',
#  'simonovic',
#  'macmath',
#  'sarabia',
#  'youssef',
#  'wolf',
#  'ba',
#  'maric',
#  'mönchengladbach',
#  'escobar',
#  'rapids',
#  'chotard',
#  'coucke',
#  'granero',
#  "dell'orco",
#  'kurt',
#  'yazici',
#  'virgil',
#  'iago',
#  'goyette',
#  'haddad',
#  'clint',
#  'miranchuk',
#  'card!johann',
#  'ziegler',
#  'gestede',
#  'obregon',
#  'ireland',
#  'card!terence',
#  'vishinuel',
#  'eve',
#  'randall',
#  'accam',
#  'wesley',
#  'hasler',
#  'andrews',
#  'arnaut',
#  'card!mateo',
#  'picault',
#  'falco',
#  'jiménez',
#  'dax',
#  'niall',
#  'mislav',
#  'delpiccolo',
#  'salvador',
#  'zvezda',
#  'kaydion',
#  'hull',
#  'thierry',
#  'injured',
#  'quenten',
#  'suk',
#  'dempsey',
#  'artem',
#  'sambinha',
#  'polio',
#  'puch',
#  'energy',
#  'holebas',
#  'card!roberto',
#  'gorobsov',
#  'mak',
#  'saeed',
#  'gobeljic',
#  'inui',
#  'rosenior',
#  'edinson',
#  'liana',
#  'alseth',
#  'sebastiaan',
#  'carmona',
#  'mulraney',
#  'vukcevic',
#  'ivan',
#  'parsemain',
#  'umtiti',
#  'neeskens',
#  'jones',
#  'tabla',
#  'guimarães',
#  'wook',
#  'stevenson',
#  'newton',
#  'own',
#  'baker',
#  'abdelhamid',
#  'fryers',
#  'villalobos',
#  'aaron',
#  'blackstenius',
#  'dynamo',
#  'iyayi',
#  'aricheel',
#  'dubois',
#  'shinji',
#  'karol',
#  'saleck',
#  'tucker',
#  'bolívar',
#  'neto',
#  'antenucci',
#  'mertz',
#  'yordan',
#  'bellis',
#  'bejarano',
#  'dahoud',
#  'benítez',
#  '3(2',
#  'moi',
#  'poku',
#  'pier',
#  'højbjerg',
#  'card!martin',
#  'filipe',
#  'betancur',
#  'okoli',
#  'erick',
#  'reynaldo',
#  'modeste',
#  'svantesson',
#  'jacopo',
#  'aron',
#  'card!jermain',
#  'milinkovic',
#  'behrens',
#  'injury',
#  'kaká',
#  'lundkvist',
#  'nazir',
#  'ocampo',
#  'gibson',
#  'wagner',
#  'giacomo',
#  'vancouver',
#  'rodriguez',
#  'pierrick',
#  'dimitry',
#  'jimenez',
#  'amad',
#  'j.c.',
#  'burgstaller',
#  'philippe',
#  ...}

# %%
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white',
                min_font_size = 10).generate(' '.join(vocab_dict['article'])) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
{k: v for k, v in sorted(processor.words['article'].items(), key=lambda item: item[1], reverse=True)}
# Out:
# {'the': 63636,
#  'a': 29317,
#  'in': 23730,
#  'to': 23187,
#  'and': 17066,
#  'of': 14216,
#  'on': 12679,
#  'for': 9857,
#  'with': 9614,
#  'from': 8155,
#  'was': 7793,
#  'his': 7756,
#  'at': 7155,
#  'but': 6902,
#  'after': 6203,
#  'goal': 6167,
#  'first': 6079,
#  'their': 5826,
#  'as': 5809,
#  'it': 5213,
#  'half': 4961,
#  'minutes': 4745,
#  'by': 4365,
#  'minute': 4273,
#  'second': 4267,
#  'had': 4063,
#  'that': 3929,
#  'when': 3794,
#  'they': 3794,
#  'an': 3480,
#  'he': 3423,
#  'league': 3413,
#  'game': 3382,
#  'we': 3363,
#  'time': 3284,
#  'off': 3143,
#  'into': 3125,
#  'have': 3108,
#  'who': 3097,
#  'win': 3088,
#  'up': 2971,
#  'two': 2920,
#  'back': 2809,
#  'points': 2798,
#  'home': 2780,
#  'season': 2743,
#  'side': 2575,
#  'over': 2543,
#  'lead': 2534,
#  'city': 2513,
#  'this': 2202,
#  'ball': 2181,
#  'match': 2133,
#  'just': 2133,
#  'out': 2115,
#  'shot': 2114,
#  '’s': 2009,
#  'goals': 2007,
#  'not': 2003,
#  'one': 1951,
#  'kick': 1947,
#  'united': 1933,
#  'against': 1878,
#  'is': 1842,
#  'penalty': 1828,
#  'victory': 1761,
#  'cross': 1719,
#  'team': 1515,
#  'while': 1512,
#  'be': 1495,
#  'top': 1486,
#  'made': 1474,
#  'four': 1458,
#  'came': 1446,
#  'only': 1444,
#  'left': 1414,
#  'stadium': 1400,
#  'games': 1397,
#  'then': 1389,
#  'through': 1382,
#  'post': 1382,
#  'corner': 1372,
#  'saturday': 1371,
#  'mls': 1359,
#  'i': 1341,
#  'new': 1337,
#  'scoring': 1309,
#  'night': 1297,
#  'goalkeeper': 1294,
#  'did': 1266,
#  'all': 1214,
#  'third': 1198,
#  'header': 1197,
#  'box': 1191,
#  'five': 1190,
#  'them': 1180,
#  'could': 1173,
#  'fc': 1173,
#  'took': 1158,
#  'put': 1152,
#  'will': 1144,
#  'away': 1143,
#  'down': 1125,
#  'draw': 1116,
#  'been': 1113,
#  'cup': 1101,
#  'liverpool': 1100,
#  'both': 1087,
#  'point': 1086,
#  'chances': 1084,
#  'final': 1077,
#  'six': 1070,
#  'right': 1068,
#  '|': 1064,
#  'close': 1057,
#  "n't": 1047,
#  'early': 1042,
#  'chelsea': 1012,
#  'champions': 1000,
#  'has': 992,
#  'since': 983,
#  'start': 982,
#  'which': 973,
#  'got': 954,
#  'end': 947,
#  'finish': 939,
#  'see': 938,
#  'also': 912,
#  'net': 911,
#  'behind': 911,
#  'west': 909,
#  'visitors': 897,
#  'manchester': 896,
#  'good': 873,
#  'effort': 872,
#  'chance': 868,
#  'arsenal': 864,
#  'run': 860,
#  'well': 859,
#  'matches': 847,
#  'headed': 839,
#  'would': 836,
#  'us': 832,
#  'now': 830,
#  'ahead': 821,
#  'sunday': 808,
#  'club': 789,
#  'long': 782,
#  'range': 778,
#  'substitute': 772,
#  'spot': 772,
#  'everton': 769,
#  'hosts': 764,
#  'forward': 757,
#  'went': 756,
#  'again': 756,
#  'set': 755,
#  'strike': 746,
#  'another': 745,
#  'fourth': 741,
#  'beat': 728,
#  'own': 728,
#  'than': 728,
#  'leicester': 727,
#  'found': 724,
#  'you': 715,
#  'winner': 713,
#  'open': 709,
#  'gave': 704,
#  'hit': 696,
#  'get': 696,
#  'wednesday': 695,
#  'no': 694,
#  'watford': 692,
#  'him': 691,
#  'burnley': 691,
#  'david': 682,
#  'way': 669,
#  'injury': 657,
#  'defeat': 657,
#  'man': 656,
#  'best': 651,
#  'manager': 649,
#  'looked': 649,
#  'make': 646,
#  'seven': 644,
#  'defender': 642,
#  'sent': 637,
#  'day': 636,
#  'striker': 633,
#  'far': 633,
#  'wide': 632,
#  'front': 627,
#  'southampton': 620,
#  'some': 619,
#  'won': 618,
#  'clear': 616,
#  'teams': 616,
#  'opened': 614,
#  'following': 614,
#  'ham': 613,
#  'line': 608,
#  'save': 600,
#  'jose': 600,
#  'bulls': 599,
#  'inside': 596,
#  'so': 596,
#  'added': 591,
#  'york': 591,
#  'seattle': 587,
#  'low': 582,
#  'brighton': 582,
#  'go': 576,
#  'struck': 573,
#  'twice': 573,
#  'union': 573,
#  'bournemouth': 573,
#  'straight': 572,
#  'sporting': 572,
#  'opening': 570,
#  'what': 570,
#  'saved': 569,
#  'level': 569,
#  'head': 568,
#  'move': 567,
#  'spurs': 560,
#  'halftime': 560,
#  'midfielder': 554,
#  'despite': 551,
#  'said': 544,
#  'bottom': 544,
#  'newcastle': 544,
#  'fifth': 535,
#  'next': 529,
#  'do': 529,
#  'toronto': 529,
#  'sc': 527,
#  'eight': 520,
#  'old': 515,
#  'can': 511,
#  'timbers': 511,
#  'sounders': 510,
#  'give': 502,
#  'card': 501,
#  'hour': 500,
#  'take': 496,
#  'if': 496,
#  'coach': 490,
#  'going': 488,
#  'year': 485,
#  'winning': 484,
#  'saw': 481,
#  'table': 479,
#  'former': 479,
#  'denied': 479,
#  'field': 472,
#  'started': 471,
#  'other': 465,
#  'unbeaten': 464,
#  'performance': 463,
#  'very': 463,
#  'mark': 462,
#  'nine': 462,
#  'better': 460,
#  'doubled': 460,
#  'being': 456,
#  'week': 455,
#  'held': 454,
#  'road': 454,
#  'much': 450,
#  'like': 447,
#  'tottenham': 446,
#  'lost': 444,
#  'most': 443,
#  'even': 437,
#  'however': 436,
#  'round': 436,
#  'diego': 435,
#  'without': 432,
#  'fans': 431,
#  'keeper': 430,
#  'san': 428,
#  'columbus': 428,
#  'de': 423,
#  'earned': 423,
#  'houston': 423,
#  'keep': 422,
#  'advantage': 422,
#  'target': 421,
#  'under': 417,
#  'still': 416,
#  'though': 416,
#  'chris': 412,
#  'wolves': 412,
#  'above': 411,
#  'about': 407,
#  'enough': 406,
#  'having': 405,
#  'dynamo': 405,
#  'saves': 404,
#  'yards': 401,
#  'find': 400,
#  'until': 400,
#  'deflected': 399,
#  'turned': 399,
#  'vancouver': 399,
#  'missed': 398,
#  'barcelona': 398,
#  'leaders': 395,
#  'finished': 393,
#  'sides': 392,
#  'rapids': 391,
#  'possession': 390,
#  'opener': 389,
#  'crossbar': 388,
#  'madrid': 378,
#  'failed': 375,
#  'james': 374,
#  'few': 372,
#  'our': 372,
#  'near': 371,
#  'whitecaps': 370,
#  'offside': 369,
#  'ended': 367,
#  'bayern': 365,
#  'colorado': 363,
#  'leg': 360,
#  'martinez': 352,
#  'hard': 350,
#  'between': 350,
#  'making': 349,
#  'shots': 349,
#  'moments': 347,
#  'any': 345,
#  'or': 345,
#  'boss': 343,
#  'big': 343,
#  'attack': 342,
#  'equaliser': 341,
#  'group': 341,
#  'inter': 340,
#  'chicago': 340,
#  'kept': 339,
#  'edge': 338,
#  'gmt': 336,
#  'sixth': 335,
#  'too': 335,
#  'continued': 332,
#  'men': 331,
#  'michael': 329,
#  'nearly': 327,
#  'full': 325,
#  'crystal': 325,
#  'volley': 324,
#  'attempt': 324,
#  'video': 323,
#  'equalizer': 323,
#  'international': 322,
#  'tuesday': 321,
#  'matt': 321,
#  'showed': 320,
#  'christian': 320,
#  'debut': 318,
#  'silva': 317,
#  'able': 314,
#  'almost': 313,
#  'many': 311,
#  'because': 310,
#  'var': 309,
#  'seventh': 309,
#  'alex': 308,
#  'jordan': 308,
#  'dortmund': 307,
#  'work': 305,
#  'pulled': 304,
#  'once': 301,
#  'converted': 299,
#  'led': 298,
#  'outside': 297,
#  'moved': 296,
#  'should': 296,
#  'loss': 293,
#  'foot': 293,
#  'minnesota': 293,
#  'broke': 292,
#  'touch': 291,
#  'eastern': 290,
#  'kamara': 289,
#  'kansas': 287,
#  'serie': 285,
#  'little': 285,
#  'defence': 285,
#  'bench': 283,
#  'fine': 283,
#  'needed': 282,
#  'brace': 281,
#  'thought': 281,
#  'cut': 281,
#  'rsl': 281,
#  'consecutive': 280,
#  'same': 280,
#  'messi': 280,
#  'western': 280,
#  'hat': 279,
#  'double': 278,
#  'kevin': 278,
#  'heading': 277,
#  'assist': 277,
#  'within': 276,
#  'rodriguez': 274,
#  'forced': 273,
#  'liga': 273,
#  'daniel': 273,
#  'need': 272,
#  'captain': 271,
#  'earlier': 270,
#  'luis': 270,
#  'extra': 270,
#  'brought': 269,
#  'title': 269,
#  'onto': 268,
#  'trick': 268,
#  'salt': 267,
#  'yellow': 266,
#  'taken': 265,
#  'bar': 265,
#  'opportunity': 265,
#  'juventus': 262,
#  'swansea': 262,
#  'given': 261,
#  'today': 261,
#  'face': 260,
#  'challenge': 260,
#  'huddersfield': 260,
#  'form': 259,
#  'host': 257,
#  'defensive': 257,
#  'norwich': 257,
#  'taking': 256,
#  'during': 256,
#  'hand': 256,
#  'high': 256,
#  'each': 256,
#  'years': 254,
#  'atletico': 249,
#  'shortly': 249,
#  'aaron': 248,
#  'stay': 248,
#  'evening': 247,
#  'several': 247,
#  'although': 247,
#  'ben': 246,
#  'foul': 245,
#  'fell': 245,
#  'yet': 245,
#  'control': 244,
#  'action': 244,
#  'times': 244,
#  'eighth': 244,
#  'defense': 244,
#  'stoke': 242,
#  'ruled': 240,
#  'thanks': 240,
#  'quick': 238,
#  'moment': 238,
#  'seconds': 238,
#  'its': 237,
#  'friday': 236,
#  'ryan': 236,
#  'afternoon': 235,
#  'picked': 235,
#  'center': 234,
#  'hopes': 233,
#  'earn': 233,
#  'zone': 233,
#  'may': 231,
#  'history': 231,
#  'jack': 231,
#  'days': 230,
#  'decision': 230,
#  'winless': 230,
#  'around': 229,
#  'finishing': 229,
#  'clean': 229,
#  'things': 228,
#  'starting': 228,
#  'antonio': 227,
#  'pushed': 227,
#  'across': 226,
#  'harry': 226,
#  'dominated': 225,
#  'pitch': 225,
#  'midfield': 225,
#  'sebastian': 224,
#  'ninth': 223,
#  'including': 221,
#  'deserved': 221,
#  'danny': 221,
#  'earthquakes': 221,
#  'helped': 220,
#  "'ve": 220,
#  'kane': 219,
#  'look': 219,
#  'series': 219,
#  'superb': 218,
#  'difficult': 218,
#  'audi': 218,
#  'attacking': 216,
#  'tally': 216,
#  'cristian': 216,
#  'whistle': 215,
#  'beating': 213,
#  'hotspur': 213,
#  'carlos': 213,
#  'leading': 212,
#  'wins': 212,
#  'allowed': 212,
#  'counter': 212,
#  'losing': 212,
#  'phillips': 212,
#  'pl': 212,
#  'think': 211,
#  'lot': 211,
#  'defending': 210,
#  'means': 210,
#  'deep': 209,
#  'ronaldo': 208,
#  'via': 208,
#  'mauro': 208,
#  'bundesliga': 208,
#  'himself': 207,
#  'position': 207,
#  'footed': 206,
#  'football': 205,
#  'equalised': 205,
#  'canada': 205,
#  'concacaf': 204,
#  'sanchez': 202,
#  'help': 202,
#  'how': 201,
#  'winger': 201,
#  'successive': 200,
#  'turn': 200,
#  'vardy': 200,
#  'curling': 199,
#  'victor': 198,
#  'wright': 198,
#  'nick': 198,
#  'higuain': 197,
#  'extended': 197,
#  'blocked': 197,
#  'proved': 196,
#  'ever': 196,
#  'rivals': 196,
#  'giovinco': 196,
#  'napoli': 195,
#  'perfect': 195,
#  'managed': 195,
#  'sean': 194,
#  'sergio': 193,
#  'juan': 192,
#  'themselves': 191,
#  'world': 191,
#  'supporters': 191,
#  "'m": 190,
#  'fouled': 190,
#  'bradley': 189,
#  'flight': 188,
#  'deadlock': 188,
#  'jesus': 188,
#  'albion': 188,
#  'never': 187,
#  'done': 187,
#  'produced': 186,
#  'weekend': 186,
#  'son': 186,
#  'thursday': 186,
#  'marco': 185,
#  'costa': 185,
#  'tie': 185,
#  'jonathan': 185,
#  'crowd': 184,
#  'stop': 184,
#  'gonzalez': 184,
#  'roberto': 182,
#  'finally': 182,
#  'due': 181,
#  'conceded': 181,
#  'quality': 181,
#  'aguero': 181,
#  'struggled': 180,
#  'sterling': 179,
#  'getting': 179,
#  'tfc': 179,
#  'summer': 178,
#  'van': 178,
#  'either': 178,
#  'bit': 177,
#  'santos': 177,
#  'championship': 177,
#  'tim': 177,
#  'throughout': 176,
#  'strong': 176,
#  'joe': 176,
#  'important': 175,
#  'handball': 175,
#  'netted': 175,
#  'deny': 173,
#  'curled': 173,
#  'cardiff': 173,
#  'excellent': 172,
#  'distance': 172,
#  'short': 172,
#  'might': 172,
#  'acosta': 172,
#  'slotted': 171,
#  'fulham': 171,
#  'n’t': 171,
#  'provided': 170,
#  'opportunities': 170,
#  'energy': 170,
#  'those': 169,
#  'visiting': 169,
#  'defeated': 169,
#  'smith': 169,
#  'drop': 168,
#  'period': 168,
#  'sheffield': 168,
#  'king': 168,
#  'appearance': 167,
#  'mistake': 167,
#  'star': 167,
#  'travel': 166,
#  'clearance': 166,
#  'whose': 165,
#  'firing': 165,
#  'brilliant': 165,
#  'stunning': 164,
#  'justin': 164,
#  'stages': 164,
#  'looking': 164,
#  'unable': 163,
#  'signing': 163,
#  'quickly': 163,
#  'sheet': 163,
#  'valencia': 162,
#  'shown': 160,
#  'less': 160,
#  'poor': 160,
#  'drive': 159,
#  'every': 159,
#  'plenty': 159,
#  'woodwork': 158,
#  'goalless': 158,
#  'sealed': 158,
#  'mourinho': 157,
#  'assistant': 157,
#  'lucas': 157,
#  'anthony': 157,
#  'barca': 157,
#  'national': 156,
#  'always': 156,
#  'december': 155,
#  'el': 155,
#  'towards': 154,
#  'know': 153,
#  'tough': 153,
#  'derby': 152,
#  'defenders': 152,
#  'diving': 152,
#  'deficit': 151,
#  'valeri': 151,
#  'town': 151,
#  'lukaku': 150,
#  'tight': 150,
#  'borussia': 150,
#  'soon': 150,
#  'couple': 149,
#  'steve': 149,
#  'mane': 149,
#  'my': 148,
#  'missing': 148,
#  'toyota': 148,
#  'brad': 148,
#  'st': 147,
#  'levelled': 146,
#  'bbc': 146,
#  'hazard': 146,
#  'tied': 146,
#  'foster': 146,
#  'juve': 145,
#  'wing': 145,
#  'rooney': 145,
#  'aston': 145,
#  'v': 145,
#  'piece': 145,
#  'wilson': 145,
#  'hope': 144,
#  'fought': 144,
#  'want': 144,
#  'utd': 144,
#  'january': 143,
#  'angle': 143,
#  'ibrahimovic': 143,
#  'began': 143,
#  'saints': 143,
#  'yard': 142,
#  'adam': 142,
#  'lewandowski': 142,
#  'raul': 142,
#  'dangerous': 142,
#  'jones': 142,
#  'told': 141,
#  'further': 141,
#  'beaten': 141,
#  'standings': 141,
#  'golden': 141,
#  'eventually': 140,
#  'gone': 140,
#  'brazilian': 140,
#  'brom': 140,
#  'ashley': 139,
#  'followed': 138,
#  'klopp': 138,
#  'speaking': 138,
#  'efforts': 138,
#  'et': 138,
#  'opponents': 137,
#  'thomas': 137,
#  'alli': 137,
#  'john': 137,
#  'key': 137,
#  'london': 137,
#  'hold': 137,
#  'lift': 137,
#  'skc': 137,
#  'zaha': 137,
#  'firmino': 136,
#  'stepped': 136,
#  'tap': 136,
#  'brian': 136,
#  'pedro': 135,
#  'stage': 135,
#  'seemed': 135,
#  'let': 135,
#  'young': 135,
#  'assists': 135,
#  'mike': 135,
#  'became': 134,
#  'awarded': 134,
#  'ran': 134,
#  'something': 134,
#  'leaves': 134,
#  'anfield': 134,
#  'accam': 134,
#  'aubameyang': 134,
#  'build': 133,
#  'charge': 133,
#  'piatti': 133,
#  'johnson': 133,
#  'happy': 132,
#  'month': 132,
#  'row': 132,
#  'hitting': 132,
#  'rashford': 132,
#  'roma': 131,
#  'subs': 131,
#  'huge': 130,
#  'wood': 130,
#  'dropped': 130,
#  'barnes': 130,
#  'munich': 129,
#  'number': 129,
#  'march': 129,
#  'jesse': 129,
#  'bruyne': 129,
#  'flick': 129,
#  'putting': 129,
#  'zardes': 129,
#  'miguel': 128,
#  'beyond': 128,
#  'pm': 128,
#  'morris': 128,
#  'must': 127,
#  'powerful': 127,
#  'bounced': 127,
#  'neither': 127,
#  'advance': 127,
#  'live': 126,
#  'these': 126,
#  'tried': 126,
#  'lineup': 126,
#  'sending': 125,
#  'quakes': 125,
#  'meanwhile': 124,
#  'safety': 124,
#  'worked': 124,
#  'confidence': 124,
#  'least': 123,
#  'push': 123,
#  'sam': 123,
#  'finding': 122,
#  'kljestan': 122,
#  'jozy': 122,
#  'hull': 122,
#  'disallowed': 121,
#  'called': 121,
#  'dramatic': 121,
#  'show': 121,
#  'trip': 121,
#  'tackle': 121,
#  'bruce': 121,
#  'jimenez': 121,
#  'tom': 121,
#  'nothing': 120,
#  'decisive': 120,
#  'davies': 120,
#  'scott': 120,
#  'dwyer': 120,
#  'deflection': 119,
#  'contest': 119,
#  'weeks': 119,
#  'squad': 119,
#  'controlled': 119,
#  'joao': 118,
#  'fashion': 118,
#  'gonzalo': 118,
#  'fabian': 118,
#  'flicked': 118,
#  'stefan': 117,
#  'netting': 117,
#  'life': 117,
#  'mexico': 117,
#  'hammers': 117,
#  'cherries': 117,
#  'miss': 116,
#  'single': 116,
#  'garcia': 116,
#  'call': 116,
#  'bull': 116,
#  'manotas': 116,
#  'usmnt': 116,
#  'manuel': 115,
#  'marked': 115,
#  'tournament': 115,
#  'arrived': 115,
#  'november': 114,
#  'gabriel': 114,
#  'gunners': 114,
#  'running': 113,
#  'slipped': 113,
#  'robles': 113,
#  'wondolowski': 113,
#  'bobby': 113,
#  'october': 112,
#  'federico': 112,
#  'loose': 112,
#  'leave': 112,
#  'race': 112,
#  'say': 112,
#  'robert': 112,
#  'mohamed': 112,
#  'tonight': 112,
#  'september': 111,
#  'argentine': 111,
#  'continue': 111,
#  'pk': 111,
#  'insurance': 111,
#  'kei': 111,
#  'dempsey': 111,
#  'knockout': 110,
#  'ground': 110,
#  'bad': 110,
#  'tyler': 110,
#  'rookie': 110,
#  'jamie': 110,
#  'tapped': 109,
#  'seal': 109,
#  'chipped': 109,
#  'williams': 109,
#  'harrison': 109,
#  'martin': 109,
#  'bst': 108,
#  'leaving': 108,
#  'grabbed': 108,
#  'crossed': 108,
#  'felt': 108,
#  'gold': 108,
#  'homegrown': 108,
#  'struggling': 107,
#  'fight': 107,
#  'jan': 107,
#  'wayne': 107,
#  'sport': 106,
#  'interval': 106,
#  'lifted': 106,
#  'closing': 106,
#  'leipzig': 106,
#  'easy': 106,
#  'josef': 106,
#  'midway': 105,
#  'eriksen': 105,
#  'instead': 105,
#  'ago': 105,
#  'used': 105,
#  'eric': 105,
#  'diaz': 105,
#  'wilder': 105,
#  'handed': 104,
#  'feel': 104,
#  'lions': 104,
#  'marc': 104,
#  'affair': 104,
#  'improved': 104,
#  'changes': 104,
#  'unmarked': 104,
#  'bmo': 104,
#  'ramos': 103,
#  'course': 103,
#  'raheem': 103,
#  'canadian': 103,
#  'felipe': 102,
#  'lose': 102,
#  'occasions': 102,
#  'gomez': 102,
#  'monday': 102,
#  'volleyed': 102,
#  'benzema': 102,
#  'abraham': 102,
#  'fantastic': 102,
#  'shootout': 102,
#  'urruti': 102,
#  'lodeiro': 102,
#  'martial': 102,
#  'solskjaer': 102,
#  'climb': 101,
#  'julian': 101,
#  'wanted': 101,
#  'why': 101,
#  'lloris': 101,
#  'does': 101,
#  'raced': 101,
#  'immediately': 101,
#  'wilfried': 101,
#  'european': 100,
#  'crucial': 100,
#  'change': 100,
#  'central': 100,
#  'clubs': 100,
#  'looks': 100,
#  'gk': 100,
#  'sapong': 100,
#  'watch': 100,
#  'veteran': 99,
#  'met': 99,
#  'easily': 99,
#  'perhaps': 99,
#  'everything': 98,
#  'attempted': 98,
#  'allowing': 98,
#  'loons': 98,
#  'nice': 97,
#  'style': 97,
#  'months': 97,
#  'me': 97,
#  'narrowly': 97,
#  'solid': 97,
#  'am': 97,
#  'foxes': 97,
#  'seen': 96,
#  'assisted': 96,
#  'such': 96,
#  'shield': 96,
#  'marcus': 96,
#  'lee': 96,
#  'trafford': 95,
#  'convert': 95,
#  'visit': 95,
#  'superbly': 95,
#  'semifinal': 95,
#  'howard': 95,
#  'counterattack': 95,
#  'meram': 95,
#  'fraser': 95,
#  'jeff': 95,
#  'gea': 95,
#  'loan': 94,
#  'april': 94,
#  'penalties': 94,
#  'nodded': 94,
#  'battle': 94,
#  'total': 94,
#  'try': 94,
#  'moves': 94,
#  'tony': 94,
#  'dos': 94,
#  'ings': 94,
#  'm': 93,
#  'soccer': 93,
#  'giving': 93,
#  ...}

# %% [markdown]
# ## Procesamiento de entidades nombradas

# %% [markdown]
# Podemos identificar los distintos equipos y jugadores utilizando los eventos.

# %%
tp = TeamPlayers()

# %%
# %%time
tp.run()
# Out:
# premier_league_2019_2020.json
# {'Matteo Guendouzi': 'Arsenal', 'Pierre-Emerick Aubameyang': 'Arsenal', 'Nicolas Pépé': 'Arsenal', 'Marcus Rashford': 'Manchester United', 'David Luiz': 'Arsenal', 'Harry Maguire': 'Manchester United', 'Mason Greenwood': 'Manchester United', 'Jesse Lingard': 'Manchester United', 'Calum Chambers': 'Arsenal', 'Scott McTominay': 'Manchester United', 'Daniel James': 'Manchester United', 'Joe Willock': 'Arsenal', 'Bukayo Saka': 'Arsenal', 'Dani Ceballos': 'Arsenal', 'Axel Tuanzebe': 'Manchester United', 'Granit Xhaka': 'Arsenal', 'Sead Kolasinac': 'Arsenal', 'Bernd Leno': 'Norwich City', 'Victor Lindelöf': 'Manchester United', 'Paul Pogba': 'Manchester United', 'Ashley Young': 'Manchester United', 'David de Gea': 'Manchester United', 'Andreas Pereira': 'Manchester United', 'Nelson': 'Arsenal', 'Fred': 'Manchester United', 'Yoshinori Muto': 'Newcastle United', 'Wilfred Ndidi': 'Leicester City', 'Paul Dummett': 'Newcastle United', 'Fabian Schär': 'Newcastle United', 'Ricardo Pereira': 'Leicester City', 'Ayoze Pérez': 'Leicester City', 'Marc Albrighton': 'Leicester City', 'Jamie Vardy': 'Leicester City', 'Ben Chilwell': 'Leicester City', 'Dennis Praet': 'Leicester City', 'DeAndre Yedlin': 'Newcastle United', 'Jamaal Lascelles': 'Newcastle United', 'Jonny Evans': 'Leicester City', 'Christian Atsu': 'Newcastle United', 'Emil Krafth': 'Newcastle United', 'Youri Tielemans': 'Leicester City', 'Andy Carroll': 'Newcastle United', 'Isaac Hayden': 'Newcastle United', 'Ki Sung-yueng': 'Newcastle United', 'John Fleck': 'Sheffield United', 'Jordan Henderson': 'Liverpool', 'Trent Alexander-Arnold': 'Liverpool', "Jack O'Connell": 'Sheffield United', 'Andrew Robertson': 'Liverpool', 'Lys Mousset': 'Sheffield United', 'Georginio Wijnaldum': 'Liverpool', 'Alex Oxlade-Chamberlain': 'Liverpool', 'Joel Matip': 'Liverpool', 'Fabinho': 'Liverpool', 'James Milner': 'Liverpool', 'Sadio Mané': 'Liverpool', 'Chris Basham': 'Sheffield United', 'Roberto Firmino': 'Liverpool', 'John Lundstram': 'Sheffield United', 'Enda Stevens': 'Sheffield United', 'Dean Henderson': 'Sheffield United', 'John Egan': 'Sheffield United', 'Virgil van Dijk': 'Liverpool', 'Divock Origi': 'Liverpool', 'Oliver McBurnie': 'Sheffield United', 'Oliver Norwood': 'Sheffield United', 'Mohamed Salah': 'Liverpool', 'Callum Robinson': 'Sheffield United', 'George Baldock': 'Sheffield United', 'Conor Hourihane': 'Aston Villa', 'Chris Wood': 'Burnley', 'Nick Pope': 'Burnley', 'Robbie Brady': 'Burnley', 'Jay Rodriguez': 'Burnley', 'Frederic Guilbert': 'Aston Villa', 'Ashley Barnes': 'Burnley', 'John McGinn': 'Aston Villa', 'Erik Pieters': 'Burnley', 'James Tarkowski': 'Burnley', 'Jack Cork': 'Burnley', 'Wesley': 'Aston Villa', 'Jack Grealish': 'Aston Villa', 'Ben Mee': 'Burnley', 'Björn Engels': 'Aston Villa', 'Matthew Lowton': 'Burnley', 'Nakamba': 'Aston Villa', 'Matt Targett': 'Aston Villa', 'Ashley Westwood': 'Burnley', 'Neil Taylor': 'Aston Villa', 'Jeff Hendrick': 'Burnley', 'Dwight McNeil': 'Burnley', 'Keinan Davis': 'Aston Villa', 'Anwar El Ghazi': 'Aston Villa', 'Felipe Anderson': 'West Ham', 'Joshua King': 'Bournemouth', 'Aaron Ramsdale': 'Bournemouth', 'Aaron Cresswell': 'West Ham', 'Jefferson Lerma': 'Bournemouth', 'Arnaut Danjuma Groeneveld': 'Bournemouth', 'Harry Wilson': 'Bournemouth', 'Jack Stacey': 'Bournemouth', 'Angelo Ogbonna': 'West Ham', 'Lukasz Fabianski': 'Liverpool', 'Pablo Fornals': 'West Ham', 'Simon Francis': 'Bournemouth', 'Jack Wilshere': 'West Ham', 'Mark Noble': 'West Ham', 'Manuel Lanzini': 'West Ham', 'Ryan Fredericks': 'West Ham', 'Roberto Jiménez': 'Burnley', 'Declan Rice': 'West Ham', 'Diego Rico': 'Bournemouth', 'Lewis Cook': 'Bournemouth', 'Callum Wilson': 'Bournemouth', 'Andriy Yarmolenko': 'West Ham', 'Nathan Aké': 'Bournemouth', 'Sébastien Haller': 'West Ham', 'Steve Cook': 'Bournemouth', 'Issa Diop': 'West Ham', 'Dominic Solanke': 'Bournemouth', 'Pascal Groß': 'Brighton', 'Ross Barkley': 'Chelsea', 'Marcos Alonso': 'Chelsea', 'Yves Bissouma': 'Brighton', 'D ...
# {'Arsenal': {'Joseph Willock', 'Matteo Guendouzi', 'Pierre-Emerick Aubameyang', 'Sead Kolasinac', 'Nicolas Pépé', 'Kieran Tierney', 'Ainsley Maitland-Niles', 'Reiss Nelson', 'David Luiz', 'Calum Chambers', 'Shkodran Mustafi', 'Joe Willock', 'Bukayo Saka', 'Eddie Nketiah', 'Dani Ceballos', 'Gabriel Martinelli', 'Nelson', 'Alexandre Lacazette', 'Granit Xhaka', 'Mesut Özil'}, 'Manchester United': {'Brandon Williams', 'Angel Gomes', 'Chong', 'Phil Jones', 'Victor Lindelöf', 'Marcus Rashford', 'Paul Pogba', 'Marcos Rojo', 'Harry Maguire', 'Ashley Young', 'Mason Greenwood', 'Jesse Lingard', 'Aaron Wan-Bissaka', 'Scott McTominay', 'Daniel James', 'Anthony Martial', 'David de Gea', 'Andreas Pereira', 'Luke Shaw', 'Juan Mata', 'Axel Tuanzebe', 'Fred', 'Bruno Fernandes'}, 'Norwich City': {'Bernd Leno', 'Vicente Guaita', 'Emiliano Buendía', 'Ibrahim Amadou', 'Adam Idah', 'Alexander Tettey', 'Patrick Roberts', 'Jamal Lewis', 'Dennis Srbeny', 'Tom Trybull', 'Todd Cantwell', 'Mario Vrancic', 'Christoph Zimmermann', 'Ondrej Duda', 'Sam Byram', 'Moritz Leitner', 'Grant Hanley', 'Max Aarons', 'Onel Hernández', 'Josip Drmic', 'Kenny McLean', 'Tim Krul', 'Ben Godfrey', 'Marco Stiepermann', 'Lukas Rupp'}, 'Newcastle United': {'Yoshinori Muto', 'Miguel Almirón', 'Matt Ritchie', 'Florian Lejeune', 'Martin Dubravka', 'Jetro Willems', 'Allan Saint-Maximin', 'Ciaran Clark', 'DeAndre Yedlin', 'Javier Manquillo', 'Dwight Gayle', 'Andy Carroll', 'Krafth', 'Paul Dummett', 'Fabian Schär', 'Jonjo Shelvey', 'Matthew Longstaff', 'Jamaal Lascelles', 'Federico Fernández', 'Christian Atsu', 'Emil Krafth', 'Isaac Hayden', 'Ki Sung-yueng'}, 'Leicester City': {'Çaglar Söyüncü', 'James Justin', 'Kasper Schmeichel', 'James Maddison', 'Demarai Gray', 'Youri Tielemans', 'Wilfred Ndidi', 'Wes Morgan', 'Ricardo Pereira', 'Ayoze Pérez', 'Marc Albrighton', 'Christian Fuchs', 'Jamie Vardy', 'Ben Chilwell', 'Dennis Praet', 'Jonny Evans', 'Nampalys Mendy', 'Mendy', 'Darren Randolph', 'Kelechi Iheanacho'}, 'Sheffield United': {'John Fleck', "Jack O'Connell", 'Chris Basham', 'Muhamed', 'Luke Freeman', 'John Lundstram', 'Enda Stevens', 'Dean Henderson', 'John Egan', 'Ben Osborn', 'Billy Sharp', 'Phil Jagielka', 'Lys Mousset', 'Oliver McBurnie', 'Oliver Norwood', 'David McGoldrick', 'Muhamed Besic', 'Callum Robinson', 'Sander Berge', 'George Baldock'}, 'Liverpool': {'Adam Lallana', 'Alex Oxlade-Chamberlain', 'Jordan Henderson', 'Trent Alexander-Arnold', 'Joel Matip', 'James Milner', 'Fabinho', 'Sadio Mané', 'Xherdan Shaqiri', 'Naby Keita', 'Roberto Firmino', 'Alexander-Arnold', 'Dejan Lovren', 'Andrew Robertson', 'Takumi Minamino', 'Virgil van Dijk', 'Joseph Gomez', 'Divock Origi', 'Lukasz Fabianski', 'Georginio Wijnaldum', 'Mohamed Salah'}, 'Aston Villa': {'Mbwana Samatta', 'Tom Heaton', 'Michael McGovern', 'Conor Hourihane', 'Jonathan Kodjia', 'Ahmed El Mohamady', 'Wesley', 'Jack Grealish', 'Björn Engels', 'Ezri Konsa Ngoyo', 'Douglas Luiz', 'Frederic Guilbert', 'Nakamba', 'Matt Targett', 'Neil Taylor', 'John McGinn', 'Daniel Drinkwater', 'Jota', 'Keinan Davis', 'Ørjan Nyland', 'Pepe Reina', 'Anwar El Ghazi'}, 'Burnley': {'Aaron Lennon', 'Aaron', 'Chris Wood', 'Nick Pope', 'Ben Mee', 'Roberto Jiménez', 'Robbie Brady', 'Charlie Taylor', 'Matthew Lowton', 'Jay Rodriguez', 'Matej Vydra', 'Johann Gudmundsson', 'Ashley Barnes', 'Ashley Westwood', 'Erik Pieters', 'James Tarkowski', 'Phil Bardsley', 'Jeff Hendrick', 'Dwight McNeil', 'Jack Cork'}, 'West Ham': {'Jack Wilshere', 'Albian Ajeti', 'Mark Noble', 'Manuel Lanzini', 'Michail Antonio', 'Felipe Anderson', 'David Martin', 'Ryan Fredericks', 'Tomas Soucek', 'Declan Rice', 'Aaron Cresswell', 'Fabián Balbuena', 'Wickham', 'Nathan Holland', 'Pablo Fornals', 'Andriy Yarmolenko', 'Robert Snodgrass', 'Jarrod Bowen', 'Carlos Sánchez', 'Angelo Ogbonna', 'Sébastien Haller', 'Issa Diop', 'Pablo Zabaleta', 'Arthur Masuaku', 'Ajeti'}, 'Bournemouth': {'Adam Smith', 'Joshua King', 'Aaron Ramsdale', 'Andrew Surman', 'Jefferson Lerma', 'Diego Rico ...
#                       player               team                    season_file
# 0           Matteo Guendouzi            Arsenal  premier_league_2019_2020.json
# 1  Pierre-Emerick Aubameyang            Arsenal  premier_league_2019_2020.json
# 2               Nicolas Pépé            Arsenal  premier_league_2019_2020.json
# 3            Marcus Rashford  Manchester United  premier_league_2019_2020.json
# 4                 David Luiz            Arsenal  premier_league_2019_2020.json
# CPU times: user 2min 22s, sys: 48 ms, total: 2min 22s
# Wall time: 2min 22s

# %%
tp.teams_players_dict
# Out:
# {'Arsenal': {'Ainsley Maitland-Niles',
#   'Alexandre Lacazette',
#   'Bukayo Saka',
#   'Calum Chambers',
#   'Dani Ceballos',
#   'David Luiz',
#   'Eddie Nketiah',
#   'Gabriel Martinelli',
#   'Granit Xhaka',
#   'Joe Willock',
#   'Joseph Willock',
#   'Kieran Tierney',
#   'Matteo Guendouzi',
#   'Mesut Özil',
#   'Nelson',
#   'Nicolas Pépé',
#   'Pierre-Emerick Aubameyang',
#   'Reiss Nelson',
#   'Sead Kolasinac',
#   'Shkodran Mustafi'},
#  'Manchester United': {'Aaron Wan-Bissaka',
#   'Andreas Pereira',
#   'Angel Gomes',
#   'Anthony Martial',
#   'Ashley Young',
#   'Axel Tuanzebe',
#   'Brandon Williams',
#   'Bruno Fernandes',
#   'Chong',
#   'Daniel James',
#   'David de Gea',
#   'Fred',
#   'Harry Maguire',
#   'Jesse Lingard',
#   'Juan Mata',
#   'Luke Shaw',
#   'Marcos Rojo',
#   'Marcus Rashford',
#   'Mason Greenwood',
#   'Paul Pogba',
#   'Phil Jones',
#   'Scott McTominay',
#   'Victor Lindelöf'},
#  'Norwich City': {'Adam Idah',
#   'Alexander Tettey',
#   'Ben Godfrey',
#   'Bernd Leno',
#   'Christoph Zimmermann',
#   'Dennis Srbeny',
#   'Emiliano Buendía',
#   'Grant Hanley',
#   'Ibrahim Amadou',
#   'Jamal Lewis',
#   'Josip Drmic',
#   'Kenny McLean',
#   'Lukas Rupp',
#   'Marco Stiepermann',
#   'Mario Vrancic',
#   'Max Aarons',
#   'Moritz Leitner',
#   'Ondrej Duda',
#   'Onel Hernández',
#   'Patrick Roberts',
#   'Sam Byram',
#   'Tim Krul',
#   'Todd Cantwell',
#   'Tom Trybull',
#   'Vicente Guaita'},
#  'Newcastle United': {'Allan Saint-Maximin',
#   'Andy Carroll',
#   'Christian Atsu',
#   'Ciaran Clark',
#   'DeAndre Yedlin',
#   'Dwight Gayle',
#   'Emil Krafth',
#   'Fabian Schär',
#   'Federico Fernández',
#   'Florian Lejeune',
#   'Isaac Hayden',
#   'Jamaal Lascelles',
#   'Javier Manquillo',
#   'Jetro Willems',
#   'Jonjo Shelvey',
#   'Ki Sung-yueng',
#   'Krafth',
#   'Martin Dubravka',
#   'Matt Ritchie',
#   'Matthew Longstaff',
#   'Miguel Almirón',
#   'Paul Dummett',
#   'Yoshinori Muto'},
#  'Leicester City': {'Ayoze Pérez',
#   'Ben Chilwell',
#   'Christian Fuchs',
#   'Darren Randolph',
#   'Demarai Gray',
#   'Dennis Praet',
#   'James Justin',
#   'James Maddison',
#   'Jamie Vardy',
#   'Jonny Evans',
#   'Kasper Schmeichel',
#   'Kelechi Iheanacho',
#   'Marc Albrighton',
#   'Mendy',
#   'Nampalys Mendy',
#   'Ricardo Pereira',
#   'Wes Morgan',
#   'Wilfred Ndidi',
#   'Youri Tielemans',
#   'Çaglar Söyüncü'},
#  'Sheffield United': {'Ben Osborn',
#   'Billy Sharp',
#   'Callum Robinson',
#   'Chris Basham',
#   'David McGoldrick',
#   'Dean Henderson',
#   'Enda Stevens',
#   'George Baldock',
#   "Jack O'Connell",
#   'John Egan',
#   'John Fleck',
#   'John Lundstram',
#   'Luke Freeman',
#   'Lys Mousset',
#   'Muhamed',
#   'Muhamed Besic',
#   'Oliver McBurnie',
#   'Oliver Norwood',
#   'Phil Jagielka',
#   'Sander Berge'},
#  'Liverpool': {'Adam Lallana',
#   'Alex Oxlade-Chamberlain',
#   'Alexander-Arnold',
#   'Andrew Robertson',
#   'Dejan Lovren',
#   'Divock Origi',
#   'Fabinho',
#   'Georginio Wijnaldum',
#   'James Milner',
#   'Joel Matip',
#   'Jordan Henderson',
#   'Joseph Gomez',
#   'Lukasz Fabianski',
#   'Mohamed Salah',
#   'Naby Keita',
#   'Roberto Firmino',
#   'Sadio Mané',
#   'Takumi Minamino',
#   'Trent Alexander-Arnold',
#   'Virgil van Dijk',
#   'Xherdan Shaqiri'},
#  'Aston Villa': {'Ahmed El Mohamady',
#   'Anwar El Ghazi',
#   'Björn Engels',
#   'Conor Hourihane',
#   'Daniel Drinkwater',
#   'Douglas Luiz',
#   'Ezri Konsa Ngoyo',
#   'Frederic Guilbert',
#   'Jack Grealish',
#   'John McGinn',
#   'Jonathan Kodjia',
#   'Jota',
#   'Keinan Davis',
#   'Matt Targett',
#   'Mbwana Samatta',
#   'Michael McGovern',
#   'Nakamba',
#   'Neil Taylor',
#   'Pepe Reina',
#   'Tom Heaton',
#   'Wesley',
#   'Ørjan Nyland'},
#  'Burnley': {'Aaron',
#   'Aaron Lennon',
#   'Ashley Barnes',
#   'Ashley Westwood',
#   'Ben Mee',
#   'Charlie Taylor',
#   'Chris Wood',
#   'Dwight McNeil',
#   'Erik Pieters',
#   'Jack Cork',
#   'James Tarkowski',
#   'Jay Rodriguez',
#   'Jeff Hendrick',
#   'Johann Gudmundsson',
#   'Matej Vydra',
#   'Matthew Lowton',
#   'Nick Pope',
#   'Phil Bardsley',
#   'Robbie Brady',
#   'Roberto Jiménez'},
#  'West Ham': {'Aaron Cresswell',
#   'Ajeti',
#   'Albian Ajeti',
#   'Andriy Yarmolenko',
#   'Angelo Ogbonna',
#   'Arthur Masuaku',
#   'Carlos Sánchez',
#   'David Martin',
#   'Declan Rice',
#   'Fabián Balbuena',
#   'Felipe Anderson',
#   'Issa Diop',
#   'Jack Wilshere',
#   'Jarrod Bowen',
#   'Manuel Lanzini',
#   'Mark Noble',
#   'Michail Antonio',
#   'Nathan Holland',
#   'Pablo Fornals',
#   'Pablo Zabaleta',
#   'Robert Snodgrass',
#   'Ryan Fredericks',
#   'Sébastien Haller',
#   'Tomas Soucek',
#   'Wickham'},
#  'Bournemouth': {'Aaron Ramsdale',
#   'Adam Smith',
#   'Andrew Surman',
#   'Angus Gunn',
#   'Arnaut Danjuma Groeneveld',
#   'Callum Wilson',
#   'Chris Mepham',
#   'Dan Gosling',
#   'Danjuma Groeneveld',
#   'Diego Rico',
#   'Dominic Solanke',
#   'Harry Wilson',
#   'Jack Simpson',
#   'Jack Stacey',
#   'Jefferson Lerma',
#   'Joshua King',
#   'Junior Stanislas',
#   'Lewis Cook',
#   'Nathan Aké',
#   'Ryan Fraser',
#   'Simon Francis',
#   'Steve Cook'},
#  'Brighton': {'Aaron Connolly',
#   'Aaron Mooy',
#   'Adam Webster',
#   'Alireza Jahanbakhsh',
#   'Bernardo',
#   'Dale Stephens',
#   'Dan Burn',
#   'Davy Pröpper',
#   'Ezequiel Schelotto',
#   'Gaëtan Bong',
#   'Glenn Murray',
#   'Leandro Trossard',
#   'Lewis Dunk',
#   'Martín Montoya',
#   'Mat Ryan',
#   'Pascal Groß',
#   'Shane Duffy',
#   'Steven Alzate',
#   'Yves Bissouma'},
#  'Chelsea': {'Antonio Rüdiger',
#   'Callum Hudson-Odoi',
#   'César Azpilicueta',
#   'Emerson',
#   'Fikayo Tomori',
#   'Giroud',
#   'Héctor Bellerín',
#   'James',
#   'Jesús Vallejo',
#   'Jorginho',
#   'Kepa Arrizabalaga',
#   'Kurt Zouma',
#   'Marcos Alonso',
#   'Mason Mount',
#   'Mateo Kovacic',
#   'Michy Batshuayi',
#   "N'Golo Kanté",
#   'Olivier Giroud',
#   'Pedro',
#   'Reece James',
#   'Rob Holding',
#   'Ross Barkley',
#   'Tammy Abraham'},
#  'Crystal Palace': {'Benteke',
#   'Cheikhou Kouyaté',
#   'Christian Benteke',
#   'Connor Wickham',
#   'Gary Cahill',
#   'Jairo Riedewald',
#   'James McArthur',
#   'James McCarthy',
#   'James Tomkins',
#   'Jeffrey Schlupp',
#   'Joel Ward',
#   'Jordan Ayew',
#   'Luka Milivojevic',
#   'Mamadou Sakho',
#   'Martin Kelly',
#   'Max Meyer',
#   'Patrick van Aanholt',
#   'Scott Dann',
#   'Wilfried Zaha'},
#  'Tottenham Hotspur': {'Ben Davies',
#   'Christian Eriksen',
#   'Danny Rose',
#   'Davinson Sánchez',
#   'Dele Alli',
#   'Eric Dier',
#   'Erik Lamela',
#   'Eriksen',
#   'Gedson Fernandes',
#   'Giovani Lo Celso',
#   'Harry Kane',
#   'Harry Winks',
#   'Hugo Lloris',
#   'Jan Vertonghen',
#   'Japhet Tanganga',
#   'Juan Foyth',
#   'Lucas Moura',
#   'Moussa Sissoko',
#   'Paulo Gazzaniga',
#   'Ryan Sessegnon',
#   'Serge Aurier',
#   'Son Heung-Min',
#   'Steven Bergwijn',
#   'Tanguy Ndombele',
#   'Toby Alderweireld',
#   'Victor Wanyama'},
#  'Southampton': {'Alex McCarthy',
#   'Alisson',
#   'Boufal',
#   'Che Adams',
#   'Cédric Soares',
#   'Danny Ings',
#   'Emile Højbjerg',
#   'Jack Stephens',
#   'James Ward-Prowse',
#   'Jan Bednarek',
#   'Jannik Vestergaard',
#   'Kevin Danso',
#   'Maya Yoshida',
#   'Michael Obafemi',
#   'Moussa Djenepo',
#   'Nathan Redmond',
#   'Oriol Romeu',
#   'Pierre',
#   'Pierre-Emile Højbjerg',
#   'Ryan Bertrand',
#   'Shane Long',
#   'Stuart Armstrong',
#   'William Smallbone',
#   'Yan Valery'},
#  'Wolverhampton Wanderers': {'Adama Traoré',
#   'Conor Coady',
#   'Daniel Podence',
#   'Diogo Jota',
#   'Jonny',
#   'João Moutinho',
#   'Leander Dendoncker',
#   'Matt Doherty',
#   'Max Kilman',
#   'Patrick Cutrone',
#   'Pedro Neto',
#   'Raúl Jiménez',
#   'Rui Patrício',
#   'Ryan Bennett',
#   'Rúben Neves',
#   'Rúben Vinagre',
#   'Willy Boly'},
#  'Watford': {'Abdoulaye Doucouré',
#   'Adam Masina',
#   'Adrian Mariappa',
#   'Andre Gray',
#   'Ben Foster',
#   'Christian Kabasele',
#   'Craig Cathcart',
#   'Craig Dawson',
#   'Danny Welbeck',
#   'Daryl Janmaat',
#   'Dimitri Foulquier',
#   'Domingos Quina',
#   'Etienne Capoue',
#   'Gerard Deulofeu',
#   'Ignacio Pussetto',
#   'Isaac Success',
#   'Ismaila Sarr',
#   'José Holebas',
#   'Kiko Femenía',
#   'Nathaniel Chalobah',
#   'Roberto Pereyra',
#   'Tom Cleverley',
#   'Troy Deeney',
#   'Will Hughes'},
#  'Manchester City': {'Agüero',
#   'Aymeric Laporte',
#   'Benjamin Mendy',
#   'Bernardo Silva',
#   'Claudio Bravo',
#   'David Silva',
#   'Eric García',
#   'Fernandinho',
#   'Gabriel Jesus',
#   'Gündogan',
#   'Ilkay Gündogan',
#   'John Stones',
#   'João Cancelo',
#   'Kevin De Bruyne',
#   'Kyle Walker',
#   'Nicolás Otamendi',
#   'Oleksandr Zinchenko',
#   'Phil Foden',
#   'Raheem Sterling',
#   'Riyad Mahrez',
#   'Rodrigo',
#   'Sergio Agüero',
#   'Wayne Hennessey'},
#  'Everton': {'Alex Iwobi',
#   'André Gomes',
#   'Bernard',
#   'Cenk Tosun',
#   'Delph',
#   'Dominic Calvert-Lewin',
#   'Fabian Delph',
#   'Gylfi Sigurdsson',
#   'Jordan Pickford',
#   'Lucas Digne',
#   'Mason Holgate',
#   'Michael Keane',
#   'Moise Kean',
#   'Richarlison',
#   'Séamus Coleman',
#   'Theo Walcott',
#   'Tom Davies',
#   'Yerry Mina'},
#  'Wolverhampton': ['Jeffrey'],
#  'Villa': ['Goal Aston']}

# %%
tp.players_teams_dict
# Out:
# {'Matteo Guendouzi': 'Arsenal',
#  'Pierre-Emerick Aubameyang': 'Arsenal',
#  'Nicolas Pépé': 'Arsenal',
#  'Marcus Rashford': 'Manchester United',
#  'David Luiz': 'Arsenal',
#  'Harry Maguire': 'Manchester United',
#  'Mason Greenwood': 'Manchester United',
#  'Jesse Lingard': 'Manchester United',
#  'Calum Chambers': 'Arsenal',
#  'Scott McTominay': 'Manchester United',
#  'Daniel James': 'Manchester United',
#  'Joe Willock': 'Arsenal',
#  'Bukayo Saka': 'Arsenal',
#  'Dani Ceballos': 'Arsenal',
#  'Axel Tuanzebe': 'Manchester United',
#  'Granit Xhaka': 'Arsenal',
#  'Sead Kolasinac': 'Arsenal',
#  'Bernd Leno': 'Norwich City',
#  'Victor Lindelöf': 'Manchester United',
#  'Paul Pogba': 'Manchester United',
#  'Ashley Young': 'Manchester United',
#  'David de Gea': 'Manchester United',
#  'Andreas Pereira': 'Manchester United',
#  'Nelson': 'Arsenal',
#  'Fred': 'Manchester United',
#  'Yoshinori Muto': 'Newcastle United',
#  'Wilfred Ndidi': 'Leicester City',
#  'Paul Dummett': 'Newcastle United',
#  'Fabian Schär': 'Newcastle United',
#  'Ricardo Pereira': 'Leicester City',
#  'Ayoze Pérez': 'Leicester City',
#  'Marc Albrighton': 'Leicester City',
#  'Jamie Vardy': 'Leicester City',
#  'Ben Chilwell': 'Leicester City',
#  'Dennis Praet': 'Leicester City',
#  'DeAndre Yedlin': 'Newcastle United',
#  'Jamaal Lascelles': 'Newcastle United',
#  'Jonny Evans': 'Leicester City',
#  'Christian Atsu': 'Newcastle United',
#  'Emil Krafth': 'Newcastle United',
#  'Youri Tielemans': 'Leicester City',
#  'Andy Carroll': 'Newcastle United',
#  'Isaac Hayden': 'Newcastle United',
#  'Ki Sung-yueng': 'Newcastle United',
#  'John Fleck': 'Sheffield United',
#  'Jordan Henderson': 'Liverpool',
#  'Trent Alexander-Arnold': 'Liverpool',
#  "Jack O'Connell": 'Sheffield United',
#  'Andrew Robertson': 'Liverpool',
#  'Lys Mousset': 'Sheffield United',
#  'Georginio Wijnaldum': 'Liverpool',
#  'Alex Oxlade-Chamberlain': 'Liverpool',
#  'Joel Matip': 'Liverpool',
#  'Fabinho': 'Liverpool',
#  'James Milner': 'Liverpool',
#  'Sadio Mané': 'Liverpool',
#  'Chris Basham': 'Sheffield United',
#  'Roberto Firmino': 'Liverpool',
#  'John Lundstram': 'Sheffield United',
#  'Enda Stevens': 'Sheffield United',
#  'Dean Henderson': 'Sheffield United',
#  'John Egan': 'Sheffield United',
#  'Virgil van Dijk': 'Liverpool',
#  'Divock Origi': 'Liverpool',
#  'Oliver McBurnie': 'Sheffield United',
#  'Oliver Norwood': 'Sheffield United',
#  'Mohamed Salah': 'Liverpool',
#  'Callum Robinson': 'Sheffield United',
#  'George Baldock': 'Sheffield United',
#  'Conor Hourihane': 'Aston Villa',
#  'Chris Wood': 'Burnley',
#  'Nick Pope': 'Burnley',
#  'Robbie Brady': 'Burnley',
#  'Jay Rodriguez': 'Burnley',
#  'Frederic Guilbert': 'Aston Villa',
#  'Ashley Barnes': 'Burnley',
#  'John McGinn': 'Aston Villa',
#  'Erik Pieters': 'Burnley',
#  'James Tarkowski': 'Burnley',
#  'Jack Cork': 'Burnley',
#  'Wesley': 'Aston Villa',
#  'Jack Grealish': 'Aston Villa',
#  'Ben Mee': 'Burnley',
#  'Björn Engels': 'Aston Villa',
#  'Matthew Lowton': 'Burnley',
#  'Nakamba': 'Aston Villa',
#  'Matt Targett': 'Aston Villa',
#  'Ashley Westwood': 'Burnley',
#  'Neil Taylor': 'Aston Villa',
#  'Jeff Hendrick': 'Burnley',
#  'Dwight McNeil': 'Burnley',
#  'Keinan Davis': 'Aston Villa',
#  'Anwar El Ghazi': 'Aston Villa',
#  'Felipe Anderson': 'West Ham',
#  'Joshua King': 'Bournemouth',
#  'Aaron Ramsdale': 'Bournemouth',
#  'Aaron Cresswell': 'West Ham',
#  'Jefferson Lerma': 'Bournemouth',
#  'Arnaut Danjuma Groeneveld': 'Bournemouth',
#  'Harry Wilson': 'Bournemouth',
#  'Jack Stacey': 'Bournemouth',
#  'Angelo Ogbonna': 'West Ham',
#  'Lukasz Fabianski': 'Liverpool',
#  'Pablo Fornals': 'West Ham',
#  'Simon Francis': 'Bournemouth',
#  'Jack Wilshere': 'West Ham',
#  'Mark Noble': 'West Ham',
#  'Manuel Lanzini': 'West Ham',
#  'Ryan Fredericks': 'West Ham',
#  'Roberto Jiménez': 'Burnley',
#  'Declan Rice': 'West Ham',
#  'Diego Rico': 'Bournemouth',
#  'Lewis Cook': 'Bournemouth',
#  'Callum Wilson': 'Bournemouth',
#  'Andriy Yarmolenko': 'West Ham',
#  'Nathan Aké': 'Bournemouth',
#  'Sébastien Haller': 'West Ham',
#  'Steve Cook': 'Bournemouth',
#  'Issa Diop': 'West Ham',
#  'Dominic Solanke': 'Bournemouth',
#  'Pascal Groß': 'Brighton',
#  'Ross Barkley': 'Chelsea',
#  'Marcos Alonso': 'Chelsea',
#  'Yves Bissouma': 'Brighton',
#  'Dale Stephens': 'Brighton',
#  'Glenn Murray': 'Brighton',
#  'Pedro': 'Chelsea',
#  'Jorginho': 'Chelsea',
#  'Mateo Kovacic': 'Chelsea',
#  'César Azpilicueta': 'Chelsea',
#  'Mat Ryan': 'Brighton',
#  'Michy Batshuayi': 'Chelsea',
#  'Dan Burn': 'Brighton',
#  'Tammy Abraham': 'Chelsea',
#  'Adam Webster': 'Brighton',
#  'Martín Montoya': 'Brighton',
#  'Steven Alzate': 'Brighton',
#  'Gaëtan Bong': 'Brighton',
#  'Fikayo Tomori': 'Chelsea',
#  'Aaron Connolly': 'Brighton',
#  'Aaron Mooy': 'Brighton',
#  'Lewis Dunk': 'Brighton',
#  'Kepa Arrizabalaga': 'Chelsea',
#  'Callum Hudson-Odoi': 'Chelsea',
#  'Vicente Guaita': 'Norwich City',
#  'Emiliano Buendía': 'Norwich City',
#  'Ibrahim Amadou': 'Norwich City',
#  'Jeffrey Schlupp': 'Crystal Palace',
#  'Patrick Roberts': 'Norwich City',
#  'Jamal Lewis': 'Norwich City',
#  'Todd Cantwell': 'Norwich City',
#  'Martin Kelly': 'Crystal Palace',
#  'Cheikhou Kouyaté': 'Crystal Palace',
#  'Moritz Leitner': 'Norwich City',
#  'Wilfried Zaha': 'Crystal Palace',
#  'Patrick van Aanholt': 'Crystal Palace',
#  'Max Aarons': 'Norwich City',
#  'Gary Cahill': 'Crystal Palace',
#  'Kenny McLean': 'Norwich City',
#  'Luka Milivojevic': 'Crystal Palace',
#  'Jordan Ayew': 'Crystal Palace',
#  'James McArthur': 'Crystal Palace',
#  'Michael McGovern': 'Aston Villa',
#  'Max Meyer': 'Crystal Palace',
#  'Joel Ward': 'Crystal Palace',
#  'James McCarthy': 'Crystal Palace',
#  'Josip Drmic': 'Norwich City',
#  'Ben Godfrey': 'Norwich City',
#  'Marco Stiepermann': 'Norwich City',
#  'Moussa Sissoko': 'Tottenham Hotspur',
#  'Tanguy Ndombele': 'Tottenham Hotspur',
#  'Stuart Armstrong': 'Southampton',
#  'Danny Rose': 'Tottenham Hotspur',
#  'James Ward-Prowse': 'Southampton',
#  'Jannik Vestergaard': 'Southampton',
#  'Jan Bednarek': 'Southampton',
#  'Hugo Lloris': 'Tottenham Hotspur',
#  'Son Heung-Min': 'Tottenham Hotspur',
#  'Christian Eriksen': 'Tottenham Hotspur',
#  'Maya Yoshida': 'Southampton',
#  'Michael Obafemi': 'Southampton',
#  'Oriol Romeu': 'Southampton',
#  'Victor Wanyama': 'Tottenham Hotspur',
#  'Nathan Redmond': 'Southampton',
#  'Eric Dier': 'Tottenham Hotspur',
#  'Ryan Bertrand': 'Southampton',
#  'Serge Aurier': 'Tottenham Hotspur',
#  'Pierre-Emile Højbjerg': 'Southampton',
#  'Harry Kane': 'Tottenham Hotspur',
#  'Eriksen': 'Tottenham Hotspur',
#  'Danny Ings': 'Southampton',
#  'Erik Lamela': 'Tottenham Hotspur',
#  'Harry Winks': 'Tottenham Hotspur',
#  'Pedro Neto': 'Wolverhampton Wanderers',
#  'José Holebas': 'Watford',
#  'Jonny': 'Wolverhampton Wanderers',
#  'Matt Doherty': 'Wolverhampton Wanderers',
#  'Leander Dendoncker': 'Wolverhampton Wanderers',
#  'Craig Dawson': 'Watford',
#  'Craig Cathcart': 'Watford',
#  'Etienne Capoue': 'Watford',
#  'Tom Cleverley': 'Watford',
#  'João Moutinho': 'Wolverhampton Wanderers',
#  'Daryl Janmaat': 'Watford',
#  'Conor Coady': 'Wolverhampton Wanderers',
#  'Roberto Pereyra': 'Watford',
#  'Andre Gray': 'Watford',
#  'Ismaila Sarr': 'Watford',
#  'Adama Traoré': 'Wolverhampton Wanderers',
#  'Gerard Deulofeu': 'Watford',
#  'Willy Boly': 'Wolverhampton Wanderers',
#  'Abdoulaye Doucouré': 'Watford',
#  'Raúl Jiménez': 'Wolverhampton Wanderers',
#  'Rui Patrício': 'Wolverhampton Wanderers',
#  'Danny Welbeck': 'Watford',
#  'Kevin De Bruyne': 'Manchester City',
#  'Nicolás Otamendi': 'Manchester City',
#  'Oleksandr Zinchenko': 'Manchester City',
#  'Kyle Walker': 'Manchester City',
#  'Lucas Digne': 'Everton',
#  'Bernardo Silva': 'Manchester City',
#  'Moise Kean': 'Everton',
#  'Theo Walcott': 'Everton',
#  'Gabriel Jesus': 'Manchester City',
#  'Gylfi Sigurdsson': 'Everton',
#  'Séamus Coleman': 'Everton',
#  'Alex Iwobi': 'Everton',
#  'Ilkay Gündogan': 'Manchester City',
#  'Fernandinho': 'Manchester City',
#  'Raheem Sterling': 'Manchester City',
#  'Yerry Mina': 'Everton',
#  'Dominic Calvert-Lewin': 'Everton',
#  'Sergio Agüero': 'Manchester City',
#  'David Silva': 'Manchester City',
#  'Riyad Mahrez': 'Manchester City',
#  'Jordan Pickford': 'Everton',
#  'Jeffrey': 'Wolverhampton',
#  'Christian Benteke': 'Crystal Palace',
#  'Diogo Jota': 'Wolverhampton Wanderers',
#  'Rúben Neves': 'Wolverhampton Wanderers',
#  'Angel Gomes': 'Manchester United',
#  'Aaron Wan-Bissaka': 'Manchester United',
#  'Robert Snodgrass': 'West Ham',
#  'Juan Mata': 'Manchester United',
#  'Pablo Zabaleta': 'West Ham',
#  'Tom Heaton': 'Aston Villa',
#  'Ainsley Maitland-Niles': 'Arsenal',
#  'Ahmed El Mohamady': 'Aston Villa',
#  'Adam Lallana': 'Liverpool',
#  "N'Golo Kanté": 'Chelsea',
#  'Kurt Zouma': 'Chelsea',
#  'Emerson': 'Chelsea',
#  'Mason Mount': 'Chelsea',
#  'Joseph Gomez': 'Liverpool',
#  'James Maddison': 'Leicester City',
#  'Demarai Gray': 'Leicester City',
#  'Lucas Moura': 'Tottenham Hotspur',
#  'Jan Vertonghen': 'Tottenham Hotspur',
#  'Toby Alderweireld': 'Tottenham Hotspur',
#  'Aaron': 'Burnley',
#  'Sam Byram': 'Norwich City',
#  'Tim Krul': 'Norwich City',
#  'Aaron Lennon': 'Burnley',
#  'Alexander Tettey': 'Norwich City',
#  'Phil Jagielka': 'Sheffield United',
#  'Fabian Delph': 'Everton',
#  'Ben Osborn': 'Sheffield United',
#  'Bernard': 'Everton',
#  'Cenk Tosun': 'Everton',
#  'Michael Keane': 'Everton',
#  'João Cancelo': 'Manchester City',
#  'Benjamin Mendy': 'Manchester City',
#  'Kiko Femenía': 'Watford',
#  'Rodrigo': 'Manchester City',
#  'Ben Foster': 'Watford',
#  'Will Hughes': 'Watford',
#  'Dimitri Foulquier': 'Watford',
#  'Jetro Willems': 'Newcastle United',
#  'Allan Saint-Maximin': 'Newcastle United',
#  'Javier Manquillo': 'Newcastle United',
#  'Miguel Almirón': 'Newcastle United',
#  'Jonjo Shelvey': 'Newcastle United',
#  'Angus Gunn': 'Bournemouth',
#  'Kevin Danso': 'Southampton',
#  'Che Adams': 'Southampton',
#  'Andrew Surman': 'Bournemouth',
#  'Cédric Soares': 'Southampton',
#  'Ryan Fraser': 'Bournemouth',
#  'Jota': 'Aston Villa',
#  'Arthur Masuaku': 'West Ham',
#  'Douglas Luiz': 'Aston Villa',
#  'Richarlison': 'Everton',
#  'Chris Mepham': 'Bournemouth',
#  'Christian Kabasele': 'Watford',
#  'Mesut Özil': 'Arsenal',
#  'Xherdan Shaqiri': 'Liverpool',
#  'Federico Fernández': 'Newcastle United',
#  'Martin Dubravka': 'Newcastle United',
#  'Davy Pröpper': 'Brighton',
#  'Shane Duffy': 'Brighton',
#  'Matej Vydra': 'Burnley',
#  'Kasper Schmeichel': 'Leicester City',
#  'Chong': 'Manchester United',
#  'Moussa Djenepo': 'Southampton',
#  'Emile Højbjerg': 'Southampton',
#  'Shane Long': 'Southampton',
#  'Billy Sharp': 'Sheffield United',
#  'David McGoldrick': 'Sheffield United',
#  'Pierre': 'Southampton',
#  'Ben Davies': 'Tottenham Hotspur',
#  'Mamadou Sakho': 'Crystal Palace',
#  'Patrick Cutrone': 'Wolverhampton Wanderers',
#  'Antonio Rüdiger': 'Chelsea',
#  'Jesús Vallejo': 'Chelsea',
#  'John Stones': 'Manchester City',
#  'Dennis Srbeny': 'Norwich City',
#  'Ryan Bennett': 'Wolverhampton Wanderers',
#  'André Gomes': 'Everton',
#  'Rúben Vinagre': 'Wolverhampton Wanderers',
#  'Dele Alli': 'Tottenham Hotspur',
#  'Giovani Lo Celso': 'Tottenham Hotspur',
#  'Davinson Sánchez': 'Tottenham Hotspur',
#  'Alexandre Lacazette': 'Arsenal',
#  'Leandro Trossard': 'Brighton',
#  'Jairo Riedewald': 'Crystal Palace',
#  'Benteke': 'Crystal Palace',
#  'Scott Dann': 'Crystal Palace',
#  'Alireza Jahanbakhsh': 'Brighton',
#  'Ezequiel Schelotto': 'Brighton',
#  'Reece James': 'Chelsea',
#  'Dan Gosling': 'Bournemouth',
#  'James': 'Chelsea',
#  'Adam Smith': 'Bournemouth',
#  'Olivier Giroud': 'Chelsea',
#  'Junior Stanislas': 'Bournemouth',
#  'Matt Ritchie': 'Newcastle United',
#  'Charlie Taylor': 'Burnley',
#  'Dwight Gayle': 'Newcastle United',
#  'Phil Bardsley': 'Burnley',
#  'Michail Antonio': 'West Ham',
#  'Alex McCarthy': 'Southampton',
#  'Jack Stephens': 'Southampton',
#  'Jarrod Bowen': 'West Ham',
#  'William Smallbone': 'Southampton',
#  'Nathaniel Chalobah': 'Watford',
#  'Alexander-Arnold': 'Liverpool',
#  'Takumi Minamino': 'Liverpool',
#  'Adam Masina': 'Watford',
#  'Troy Deeney': 'Watford',
#  'Alisson': 'Southampton',
#  'Grant Hanley': 'Norwich City',
#  'Ondrej Duda': 'Norwich City',
#  'Lukas Rupp': 'Norwich City',
#  'Kelechi Iheanacho': 'Leicester City',
#  'Naby Keita': 'Liverpool',
#  'Tomas Soucek': 'West Ham',
#  'Luke Shaw': 'Manchester United',
#  'Anthony Martial': 'Manchester United',
#  'Bruno Fernandes': 'Manchester United',
#  'Eddie Nketiah': 'Arsenal',
#  'Héctor Bellerín': 'Chelsea',
#  'Shkodran Mustafi': 'Arsenal',
#  'Japhet Tanganga': 'Tottenham Hotspur',
#  'Giroud': 'Chelsea',
#  'Steven Bergwijn': 'Tottenham Hotspur',
#  'Sander Berge': 'Sheffield United',
#  'Mbwana Samatta': 'Aston Villa',
#  'Ezri Konsa Ngoyo': 'Aston Villa',
#  'Pepe Reina': 'Aston Villa',
#  'Christian Fuchs': 'Leicester City',
#  'Çaglar Söyüncü': 'Leicester City',
#  'Aymeric Laporte': 'Manchester City',
#  'Phil Foden': 'Manchester City',
#  'Gündogan': 'Manchester City',
#  'Brandon Williams': 'Manchester United',
#  'Gedson Fernandes': 'Tottenham Hotspur',
#  'Daniel Drinkwater': 'Aston Villa',
#  'Ciaran Clark': 'Newcastle United',
#  'Joseph Willock': 'Arsenal',
#  'Daniel Podence': 'Wolverhampton Wanderers',
#  'Wes Morgan': 'Leicester City',
#  'James Tomkins': 'Crystal Palace',
#  'Tom Davies': 'Everton',
#  'Ignacio Pussetto': 'Watford',
#  'Adrian Mariappa': 'Watford',
#  'Gabriel Martinelli': 'Arsenal',
#  'Boufal': 'Southampton',
#  'Mario Vrancic': 'Norwich City',
#  'Christoph Zimmermann': 'Norwich City',
#  'Isaac Success': 'Watford',
#  'Reiss Nelson': 'Arsenal',
#  'Max Kilman': 'Wolverhampton Wanderers',
#  'Eric García': 'Manchester City',
#  'Agüero': 'Manchester City',
#  'Muhamed Besic': 'Sheffield United',
#  'Florian Lejeune': 'Newcastle United',
#  'Delph': 'Everton',
#  'Mason Holgate': 'Everton',
#  'Jonathan Kodjia': 'Aston Villa',
#  'Goal Aston': 'Villa',
#  'Juan Foyth': 'Tottenham Hotspur',
#  'Ryan Sessegnon': 'Tottenham Hotspur',
#  'Onel Hernández': 'Norwich City',
#  'Tom Trybull': 'Norwich City',
#  'James Justin': 'Leicester City',
#  'Fabián Balbuena': 'West Ham',
#  'Carlos Sánchez': 'West Ham',
#  'Nampalys Mendy': 'Leicester City',
#  'Mendy': 'Leicester City',
#  'Ajeti': 'West Ham',
#  'Johann Gudmundsson': 'Burnley',
#  'Claudio Bravo': 'Manchester City',
#  'Bernardo': 'Brighton',
#  'Jack Simpson': 'Bournemouth',
#  'Connor Wickham': 'Crystal Palace',
#  'Wickham': 'West Ham',
#  'Matthew Longstaff': 'Newcastle United',
#  'Krafth': 'Newcastle United',
#  'Paulo Gazzaniga': 'Tottenham Hotspur',
#  'Luke Freeman': 'Sheffield United',
#  'Domingos Quina': 'Watford',
#  'David Martin': 'West Ham',
#  'Kieran Tierney': 'Arsenal',
#  'Nathan Holland': 'West Ham',
#  'Dejan Lovren': 'Liverpool',
#  'Danjuma Groeneveld': 'Bournemouth',
#  'Darren Randolph': 'Leicester City',
#  'Phil Jones': 'Manchester United',
#  'Rob Holding': 'Chelsea',
#  'Ørjan Nyland': 'Aston Villa',
#  'Adam Idah': 'Norwich City',
#  'Muhamed': 'Sheffield United',
#  'Yan Valery': 'Southampton',
#  'Marcos Rojo': 'Manchester United',
#  'Albian Ajeti': 'West Ham',
#  'Wayne Hennessey': 'Manchester City'}

# %%
tp = TeamPlayers()

# %%
# %%time
tp.run_file('french_ligue_one_2019_2020.json')
# Out:
# https://www.bbc.com/sport/football/50869599
# {'Paris Saint Germain'}
# ['Lineups are announced and players are warming up.', 'First Half begins.', 'Attempt missed. Mauro Icardi (Paris Saint Germain) header from very close range is too high. Assisted by Thomas Meunier with a cross.', 'Attempt missed. Ángel Di María (Paris Saint Germain) left footed shot from the centre of the box is too high. Assisted by Kylian Mbappé with a cross.', 'Foul by Arturo Calabresi (Amiens).', 'Neymar (Paris Saint Germain) wins a free kick on the left wing.', 'Goal!  Paris Saint Germain 1, Amiens 0. Kylian Mbappé (Paris Saint Germain) right footed shot from the centre of the box to the bottom left corner. Assisted by Neymar with a through ball following a fast break.', 'Thomas Monconduit (Amiens) wins a free kick on the left wing.', 'Foul by Thiago Silva (Paris Saint Germain).', 'John Stiven Mendoza (Amiens) wins a free kick on the left wing.', 'Foul by Thomas Meunier (Paris Saint Germain).', 'Attempt saved. Ángel Di María (Paris Saint Germain) left footed shot from the centre of the box is saved in the top centre of the goal. Assisted by Neymar with a through ball.', 'Attempt blocked. Thomas Monconduit (Amiens) right footed shot from outside the box is blocked. Assisted by Eddy Gnahore.', 'Corner,  Amiens. Conceded by Leandro Paredes.', 'Attempt missed. Bongani Zungu (Amiens) header from the centre of the box is just a bit too high. Assisted by Thomas Monconduit with a cross following a corner.', 'Foul by John Stiven Mendoza (Amiens).', 'Thomas Meunier (Paris Saint Germain) wins a free kick in the defensive half.', 'Substitution, Paris Saint Germain. Marco Verratti replaces Abdou Diallo because of an injury.', 'Attempt saved. Kylian Mbappé (Paris Saint Germain) right footed shot from a difficult angle on the right is saved in the top centre of the goal.', 'Foul by Bongani Zungu (Amiens).', 'Neymar (Paris Saint Germain) wins a free kick in the attacking half.', 'Moussa Konaté (Amiens) wins a free kick in the defensive half.', 'Foul by Leandro Paredes (Paris Saint Germain).', 'Foul by Eddy Gnahore (Amiens).', 'Ángel Di María (Paris Saint Germain) wins a free kick in the defensive half.', 'Eddy Gnahore (Amiens) is shown the yellow card for a bad foul.', 'Attempt saved. Neymar (Paris Saint Germain) left footed shot from outside the box is saved in the centre of the goal. Assisted by Marco Verratti.', 'Attempt blocked. Ángel Di María (Paris Saint Germain) right footed shot from the centre of the box is blocked.', 'Attempt saved. Leandro Paredes (Paris Saint Germain) right footed shot from outside the box is saved in the bottom right corner. Assisted by Ángel Di María.', 'Attempt blocked. Neymar (Paris Saint Germain) right footed shot from the right side of the six yard box is blocked.', 'Corner,  Paris Saint Germain. Conceded by Bakaye Dibassy.', 'Bongani Zungu (Amiens) wins a free kick in the defensive half.', 'Foul by Leandro Paredes (Paris Saint Germain).', 'Foul by Arturo Calabresi (Amiens).', 'Neymar (Paris Saint Germain) wins a free kick in the defensive half.', 'Thomas Monconduit (Amiens) wins a free kick in the defensive half.', 'Foul by Neymar (Paris Saint Germain).', 'John Stiven Mendoza (Amiens) wins a free kick in the defensive half.', 'Foul by Thomas Meunier (Paris Saint Germain).', 'Attempt blocked. John Stiven Mendoza (Amiens) left footed shot from outside the box is blocked. Assisted by Eddy Gnahore.', 'Corner,  Amiens. Conceded by Thiago Silva.', 'Foul by Moussa Konaté (Amiens).', 'Marco Verratti (Paris Saint Germain) wins a free kick in the defensive half.', 'Bongani Zungu (Amiens) wins a free kick in the defensive half.', 'Foul by Leandro Paredes (Paris Saint Germain).', 'Attempt saved. Kylian Mbappé (Paris Saint Germain) right footed shot from a difficult angle on the right is saved in the bottom right corner. Assisted by Marco Verratti.', 'Corner,  Paris Saint Germain. Conceded by Régis Gurtner.', 'Offside, Paris Saint Germain. Leandro Paredes tries a through ball, but Ángel Di María is caught offside.' ...
# [[('First', 'ORDINAL'), ('Half', 'CARDINAL')], [('Mauro Icardi', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Thomas Meunier', 'PERSON')], [('Ángel Di María', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Kylian Mbappé', 'PERSON')], [('Arturo Calabresi', 'ORG')], [('Neymar (', 'ORG')], [('Paris Saint Germain', 'ORG'), ('1', 'CARDINAL'), ('0', 'DATE'), ('Kylian Mbappé', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Neymar', 'ORG')], [('Thomas Monconduit', 'PERSON')], [('Thiago Silva', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('John Stiven Mendoza', 'PERSON')], [('Thomas Meunier', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Ángel Di María', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Neymar', 'ORG')], [('Thomas Monconduit', 'PERSON'), ('Eddy Gnahore', 'PERSON')], [('Leandro Paredes', 'PERSON')], [('Bongani Zungu', 'PERSON'), ('Thomas Monconduit', 'PERSON')], [('John Stiven Mendoza', 'PERSON')], [('Thomas Meunier', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('half', 'CARDINAL')], [('Paris Saint Germain', 'FAC'), ('Marco Verratti', 'PERSON'), ('Abdou Diallo', 'PERSON')], [('Kylian Mbappé', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Bongani Zungu', 'PERSON')], [('Neymar (', 'ORG'), ('half', 'CARDINAL')], [('Moussa Konaté', 'PERSON'), ('half', 'CARDINAL')], [('Leandro Paredes', 'ORG'), ('Paris Saint Germain', 'ORG')], [('Eddy Gnahore', 'PERSON')], [('Ángel Di María', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('half', 'CARDINAL')], [('Eddy Gnahore', 'PERSON')], [('Marco Verratti', 'PERSON')], [('Ángel Di María', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Leandro Paredes', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Ángel Di María', 'PERSON')], [('six', 'CARDINAL')], [('Paris Saint Germain', 'FAC'), ('Bakaye Dibassy', 'ORG')], [('Bongani Zungu', 'PERSON'), ('half', 'CARDINAL')], [('Leandro Paredes', 'ORG'), ('Paris Saint Germain', 'ORG')], [('Arturo Calabresi', 'ORG')], [('Neymar (', 'ORG'), ('half', 'CARDINAL')], [('Thomas Monconduit', 'PERSON'), ('half', 'CARDINAL')], [('Neymar (Paris Saint Germain', 'ORG')], [('John Stiven Mendoza', 'PERSON'), ('half', 'CARDINAL')], [('Thomas Meunier', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('John Stiven Mendoza', 'PERSON'), ('Eddy Gnahore', 'PERSON')], [('Thiago Silva', 'PERSON')], [('Moussa Konaté', 'PERSON')], [('Marco Verratti', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('half', 'CARDINAL')], [('Bongani Zungu', 'PERSON'), ('half', 'CARDINAL')], [('Leandro Paredes', 'ORG'), ('Paris Saint Germain', 'ORG')], [('Kylian Mbappé', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Marco Verratti', 'PERSON')], [('Paris Saint Germain', 'FAC'), ('Régis Gurtner', 'PERSON')], [('Paris Saint Germain', 'FAC'), ('Leandro Paredes', 'PERSON'), ('Ángel Di María', 'PERSON')], [('First', 'ORDINAL'), ('Half', 'CARDINAL'), ('Paris Saint Germain 1', 'ORG')], [('Second', 'ORDINAL'), ('Half', 'CARDINAL'), ('Paris Saint Germain 1', 'ORG'), ('0', 'CARDINAL')], [('Paris Saint Germain 2', 'ORG'), ('Neymar', 'GPE'), ('Mauro Icardi', 'PERSON')], [('Moussa Konaté', 'PERSON'), ('half', 'CARDINAL')], [('Marco Verratti', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Moussa Konaté', 'PERSON'), ('half', 'CARDINAL')], [('Thiago Silva', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('John Stiven Mendoza', 'PERSON')], [('Fousseni Diabaté', 'ORG')], [('Marco Verratti', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('John Stiven Mendoza', 'PERSON')], [('Arturo Calabresi', 'ORG')], [('Neymar (', 'ORG')], [('Ángel Di María', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Kylian Mbappé', 'PERSON')], [('Fousseni Diabaté', 'ORG'), ('half', 'CARDINAL')], [('Thiago Silva', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Thomas Meunier', 'PERSON')], [('Paris Saint Germain', 'FAC'), ('Thilo Kehrer', 'PERSON'), ('Thiago Silva', 'PERSON')], [('Ángel Di María', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Neymar', 'GPE')], [('Kylian Mbappé', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Marco Verratti', 'PERSON')], [('Paris Saint Germa ...
# No article or events for https://www.bbc.com/sport/football/50275019
# https://www.bbc.com/sport/football/51690379
# {'Paris Saint Germain'}
# ['Lineups are announced and players are warming up.', 'First Half begins.', 'Attempt saved. Mama Baldé (Dijon) right footed shot from outside the box is saved in the bottom left corner.', 'Attempt missed. Marquinhos (Paris Saint Germain) left footed shot from outside the box misses to the right.', 'Goal!  Paris Saint Germain 1, Dijon 0. Pablo Sarabia (Paris Saint Germain) left footed shot from the centre of the box to the bottom right corner. Assisted by Marquinhos.', 'Mickaël Alphonse (Dijon) wins a free kick in the defensive half.', 'Foul by Edinson Cavani (Paris Saint Germain).', 'Attempt saved. Thilo Kehrer (Paris Saint Germain) header from very close range is saved in the bottom left corner. Assisted by Pablo Sarabia with a cross.', 'Attempt missed. Kylian Mbappé (Paris Saint Germain) header from the centre of the box is just a bit too high. Assisted by Ángel Di María.', 'Attempt missed. Pablo Sarabia (Paris Saint Germain) header from the left side of the six yard box misses to the left. Assisted by Kylian Mbappé with a cross.', 'Foul by Didier Ndong (Dijon).', 'Thilo Kehrer (Paris Saint Germain) wins a free kick on the right wing.', 'Mama Baldé (Dijon) wins a free kick on the right wing.', 'Foul by Juan Bernat (Paris Saint Germain).', 'Juan Bernat (Paris Saint Germain) is shown the yellow card for a bad foul.', 'Attempt missed. Hamza Mendyl (Dijon) left footed shot from the left side of the box is too high. Assisted by Stephy Mavididi.', 'Substitution, Paris Saint Germain. Julian Draxler replaces Ángel Di María because of an injury.', 'Júlio Tavares (Dijon) wins a free kick in the defensive half.', 'Foul by Presnel Kimpembe (Paris Saint Germain).', 'Attempt missed. Hamza Mendyl (Dijon) left footed shot from a difficult angle on the left misses to the left. Assisted by Mickaël Alphonse with a cross.', 'Offside, Paris Saint Germain. Pablo Sarabia tries a through ball, but Kylian Mbappé is caught offside.', 'Offside, Paris Saint Germain. Juan Bernat tries a through ball, but Pablo Sarabia is caught offside.', 'Attempt saved. Julian Draxler (Paris Saint Germain) right footed shot from the right side of the box is saved in the bottom right corner.', 'Corner,  Paris Saint Germain. Conceded by Rúnar Alex Rúnarsson.', 'Attempt saved. Juan Bernat (Paris Saint Germain) left footed shot from the centre of the box is saved in the bottom right corner.', 'Corner,  Paris Saint Germain. Conceded by Wesley Lautoa.', 'Attempt saved. Julian Draxler (Paris Saint Germain) right footed shot from the right side of the box is saved in the centre of the goal. Assisted by Edinson Cavani.', 'Foul by Didier Ndong (Dijon).', 'Idrissa Gueye (Paris Saint Germain) wins a free kick in the defensive half.', 'Attempt missed. Mickaël Alphonse (Dijon) right footed shot from the right side of the box misses to the left. Assisted by Stephy Mavididi.', 'Attempt missed. Edinson Cavani (Paris Saint Germain) right footed shot from very close range is too high. Assisted by Kylian Mbappé.', 'Attempt saved. Kylian Mbappé (Paris Saint Germain) right footed shot from the right side of the box is saved in the centre of the goal. Assisted by Idrissa Gueye.', 'Corner,  Paris Saint Germain. Conceded by Rúnar Alex Rúnarsson.', 'Attempt missed. Stephy Mavididi (Dijon) left footed shot from outside the box misses to the right.', 'Attempt missed. Kylian Mbappé (Paris Saint Germain) right footed shot from outside the box is close, but misses to the right. Assisted by Julian Draxler.', 'Corner,  Paris Saint Germain. Conceded by Bruno Ecuele Manga.', 'First Half ends, Paris Saint Germain 1, Dijon 0.', 'Second Half begins Paris Saint Germain 1, Dijon 0.', 'Corner,  Paris Saint Germain. Conceded by Mickaël Alphonse.', 'Attempt missed. Marquinhos (Paris Saint Germain) header from the centre of the box is too high. Assisted by Pablo Sarabia with a cross following a corner.', 'Mama Baldé (Dijon) wins a free kick in the attacking half.', 'Foul by Presnel Kimpembe (Paris Saint Germain) ...
# [[('First', 'ORDINAL'), ('Half', 'CARDINAL')], [], [('Paris Saint Germain', 'ORG')], [('Paris Saint Germain', 'ORG'), ('1', 'CARDINAL'), ('0', 'CARDINAL'), ('Pablo Sarabia', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Marquinhos', 'ORG')], [('Mickaël Alphonse', 'PERSON'), ('half', 'CARDINAL')], [('Edinson Cavani', 'ORG'), ('Paris Saint Germain', 'ORG')], [('Thilo Kehrer', 'PERSON'), ('Pablo Sarabia', 'PERSON')], [('Kylian Mbappé', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Ángel Di María', 'PERSON')], [('Pablo Sarabia', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('six', 'CARDINAL'), ('Kylian Mbappé', 'PERSON')], [], [('Thilo Kehrer', 'PERSON')], [], [('Juan Bernat', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Juan Bernat', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Hamza Mendyl', 'PERSON'), ('Stephy Mavididi', 'GPE')], [('Paris Saint Germain', 'FAC'), ('Julian', 'NORP'), ('Ángel Di María', 'PERSON')], [('Júlio Tavares', 'PERSON'), ('half', 'CARDINAL')], [('Presnel Kimpembe', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Hamza Mendyl', 'PERSON'), ('Mickaël Alphonse', 'PERSON')], [('Paris Saint Germain', 'FAC'), ('Pablo Sarabia', 'PERSON'), ('Kylian Mbappé', 'PERSON')], [('Paris Saint Germain', 'FAC'), ('Juan Bernat', 'PERSON'), ('Pablo Sarabia', 'PERSON')], [('Julian Draxler', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Paris Saint Germain', 'FAC'), ('Rúnar Alex Rúnarsson', 'PERSON')], [('Juan Bernat', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Paris Saint Germain', 'FAC'), ('Wesley Lautoa', 'PERSON')], [('Julian Draxler', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Edinson Cavani', 'ORG')], [], [('Idrissa Gueye', 'PERSON'), ('half', 'CARDINAL')], [('Mickaël Alphonse', 'PERSON'), ('Stephy Mavididi', 'GPE')], [('Edinson Cavani', 'ORG'), ('Paris Saint Germain', 'ORG'), ('Kylian Mbappé', 'PERSON')], [('Kylian Mbappé', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Idrissa Gueye', 'PERSON')], [('Paris Saint Germain', 'FAC'), ('Rúnar Alex Rúnarsson', 'PERSON')], [('Stephy Mavididi', 'PERSON')], [('Kylian Mbappé', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Julian Draxler', 'PERSON')], [('Paris Saint Germain', 'FAC'), ('Bruno Ecuele Manga', 'ORG')], [('First', 'ORDINAL'), ('Half', 'CARDINAL'), ('Paris Saint Germain 1', 'ORG'), ('0', 'CARDINAL')], [('Second', 'ORDINAL'), ('Half', 'CARDINAL'), ('Paris Saint Germain 1', 'ORG'), ('0', 'CARDINAL')], [('Paris Saint Germain', 'FAC'), ('Mickaël Alphonse', 'PERSON')], [('Paris Saint Germain', 'ORG'), ('Pablo Sarabia', 'PERSON')], [('half', 'CARDINAL')], [('Presnel Kimpembe', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Wesley Lautoa', 'PERSON'), ('Júlio Tavares', 'PERSON')], [('Pablo Sarabia', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Kylian Mbappé', 'PERSON')], [('Edinson Cavani', 'ORG'), ('Paris Saint Germain', 'ORG'), ('Kylian Mbappé', 'PERSON')], [('Kylian Mbappé', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('six', 'CARDINAL'), ('Edinson Cavani', 'ORG')], [('Paris Saint Germain', 'FAC'), ('Hamza Mendyl', 'PERSON')], [('Paris Saint Germain', 'FAC'), ('Mickaël Alphonse', 'PERSON')], [('Frédéric Sammaritano', 'PERSON'), ('Stephy Mavididi', 'GPE')], [('Frédéric Sammaritano', 'PERSON'), ('half', 'CARDINAL')], [('Idrissa Gueye', 'PERSON')], [('Kylian Mbappé', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Pablo Sarabia', 'PERSON')], [('Pablo Sarabia', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Idrissa Gueye', 'PERSON')], [('Paris Saint Germain', 'FAC'), ('Mauro Icardi', 'PERSON'), ('Edinson Cavani', 'PERSON')], [('Paris Saint Germain', 'FAC'), ('Tanguy Kouassi', 'PERSON')], [('Amalfitano', 'PERSON'), ('Wesley Lautoa', 'PERSON')], [('Senou Coulibaly', 'PERSON')], [('Pablo Sarabia', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('the attacking half', 'DATE')], [('Paris Saint Germain 2', 'ORG'), ('0', 'DATE'), ('Kylian Mbappé', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Julian Draxler', 'PERSON')], [('Jhonder Cádiz', 'PERSON'), ('Senou Coulibaly', 'PERSON')], [('Mickaël Alpho ...
# https://www.bbc.com/sport/football/51517956
# {'Paris Saint Germain'}
# ['Lineups are announced and players are warming up.', 'First Half begins.', 'Foul by Alexis Blin (Amiens).', 'Ángel Di María (Paris Saint Germain) wins a free kick on the right wing.', 'Foul by Alexis Blin (Amiens).', 'Idrissa Gueye (Paris Saint Germain) wins a free kick in the defensive half.', 'Goal!  Amiens 1, Paris Saint Germain 0. Serhou Guirassy (Amiens) right footed shot from the right side of the box to the centre of the goal. Assisted by Gaël Kakuta with a through ball.', 'Attempt missed. Edinson Cavani (Paris Saint Germain) right footed shot from the centre of the box is close, but misses to the left. Assisted by Julian Draxler with a cross.', 'Attempt missed. Ángel Di María (Paris Saint Germain) left footed shot from outside the box is too high. Assisted by Mauro Icardi.', 'Serhou Guirassy (Amiens) wins a free kick on the left wing.', 'Foul by Ander Herrera (Paris Saint Germain).', 'Foul by Gaël Kakuta (Amiens).', 'Leandro Paredes (Paris Saint Germain) wins a free kick in the defensive half.', 'Foul by Bongani Zungu (Amiens).', 'Julian Draxler (Paris Saint Germain) wins a free kick in the defensive half.', 'Attempt saved. Edinson Cavani (Paris Saint Germain) right footed shot from a difficult angle on the right is saved in the top left corner. Assisted by Ángel Di María with a through ball.', 'Attempt missed. Juan Ferney Otero (Amiens) right footed shot from outside the box is close, but misses the top right corner following a fast break.', 'Juan Ferney Otero (Amiens) wins a free kick in the defensive half.', 'Foul by Julian Draxler (Paris Saint Germain).', 'Attempt missed. Serhou Guirassy (Amiens) right footed shot from long range on the left is close, but misses to the right. Assisted by Haitam Aleesami.', 'Attempt saved. Serhou Guirassy (Amiens) right footed shot from the right side of the box is saved in the centre of the goal. Assisted by Juan Ferney Otero.', 'Corner,  Amiens. Conceded by Keylor Navas.', 'Attempt blocked. Ander Herrera (Paris Saint Germain) right footed shot from outside the box is blocked. Assisted by Idrissa Gueye.', 'Corner,  Paris Saint Germain. Conceded by Nicholas Opoku.', 'Foul by Bongani Zungu (Amiens).', 'Leandro Paredes (Paris Saint Germain) wins a free kick in the defensive half.', 'Foul by Serhou Guirassy (Amiens).', 'Thiago Silva (Paris Saint Germain) wins a free kick in the defensive half.', 'Alexis Blin (Amiens) wins a free kick in the defensive half.', 'Foul by Julian Draxler (Paris Saint Germain).', 'Goal!  Amiens 2, Paris Saint Germain 0. Gaël Kakuta (Amiens) left footed shot from the left side of the box to the top right corner. Assisted by Fousseni Diabaté.', 'Foul by Arturo Calabresi (Amiens).', 'Leandro Paredes (Paris Saint Germain) wins a free kick on the left wing.', 'Corner,  Paris Saint Germain. Conceded by Arturo Calabresi.', 'Attempt saved. Mauro Icardi (Paris Saint Germain) header from the centre of the box is saved in the centre of the goal. Assisted by Julian Draxler with a cross.', 'Attempt missed. Serhou Guirassy (Amiens) right footed shot from the centre of the box is too high. Assisted by Fousseni Diabaté.', 'Foul by Arturo Calabresi (Amiens).', 'Julian Draxler (Paris Saint Germain) wins a free kick in the defensive half.', 'Foul by Haitam Aleesami (Amiens).', 'Ángel Di María (Paris Saint Germain) wins a free kick on the right wing.', 'Goal!  Amiens 3, Paris Saint Germain 0. Fousseni Diabaté (Amiens) left footed shot from the left side of the box to the bottom right corner. Assisted by Gaël Kakuta following a fast break.', 'Arturo Calabresi (Amiens) wins a free kick on the right wing.', 'Foul by Mauro Icardi (Paris Saint Germain).', 'Foul by Serhou Guirassy (Amiens).', 'Nianzou Kouassi (Paris Saint Germain) wins a free kick in the defensive half.', 'Foul by Aurélien Chedjou (Amiens).', 'Mauro Icardi (Paris Saint Germain) wins a free kick on the right wing.', 'Corner,  Paris Saint Germain. Conceded by Régis Gurtner.', 'Goal!  Amiens 3, Paris Saint Germain 1. An ...
# [[('First', 'ORDINAL'), ('Half', 'CARDINAL')], [('Alexis Blin', 'PERSON')], [('Ángel Di María', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Alexis Blin', 'PERSON')], [('Idrissa Gueye', 'PERSON'), ('half', 'CARDINAL')], [('1', 'CARDINAL'), ('Paris Saint Germain 0', 'ORG'), ('Serhou Guirassy', 'PERSON'), ('Gaël Kakuta', 'PERSON')], [('Edinson Cavani', 'ORG'), ('Paris Saint Germain', 'ORG'), ('Julian Draxler', 'PERSON')], [('Ángel Di María', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Mauro Icardi', 'PERSON')], [('Serhou Guirassy', 'PERSON')], [('Ander Herrera', 'ORG'), ('Paris Saint Germain', 'ORG')], [], [('Leandro Paredes', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('half', 'CARDINAL')], [('Bongani Zungu', 'PERSON')], [('Julian Draxler', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('half', 'CARDINAL')], [('Edinson Cavani', 'ORG'), ('Paris Saint Germain', 'ORG'), ('Ángel Di María', 'PERSON')], [('Juan Ferney Otero', 'PERSON')], [('Juan Ferney Otero', 'PERSON'), ('half', 'CARDINAL')], [('Julian Draxler', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Serhou Guirassy', 'PERSON'), ('Haitam Aleesami', 'PERSON')], [('Serhou Guirassy', 'PERSON'), ('Juan Ferney Otero', 'PERSON')], [('Keylor Navas', 'PERSON')], [('Idrissa Gueye', 'PERSON')], [('Paris Saint Germain', 'FAC'), ('Nicholas Opoku', 'PERSON')], [('Bongani Zungu', 'PERSON')], [('Leandro Paredes', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('half', 'CARDINAL')], [('Serhou Guirassy', 'PERSON')], [('Thiago Silva', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('half', 'CARDINAL')], [('Alexis Blin', 'PERSON'), ('half', 'CARDINAL')], [('Julian Draxler', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('2', 'CARDINAL'), ('Paris Saint Germain 0', 'ORG'), ('Gaël Kakuta', 'PERSON'), ('Amiens', 'WORK_OF_ART'), ('Fousseni Diabaté', 'PERSON')], [('Arturo Calabresi', 'ORG')], [('Leandro Paredes', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Paris Saint Germain', 'FAC'), ('Arturo Calabresi', 'ORG')], [('Mauro Icardi', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Julian Draxler', 'PERSON')], [('Serhou Guirassy', 'PERSON'), ('Fousseni Diabaté', 'PERSON')], [('Arturo Calabresi', 'ORG')], [('Julian Draxler', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('half', 'CARDINAL')], [('Haitam Aleesami', 'PERSON')], [('Ángel Di María', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('3', 'CARDINAL'), ('Paris Saint Germain 0', 'FAC'), ('Gaël Kakuta', 'PERSON')], [('Arturo Calabresi', 'ORG')], [('Mauro Icardi', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Serhou Guirassy', 'PERSON')], [('Nianzou Kouassi', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('half', 'CARDINAL')], [('Aurélien Chedjou', 'PERSON')], [('Mauro Icardi', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Paris Saint Germain', 'FAC'), ('Régis Gurtner', 'PERSON')], [('3', 'CARDINAL'), ('Paris Saint Germain 1', 'ORG'), ('Paris Saint Germain', 'ORG')], [('First', 'ORDINAL'), ('Half', 'CARDINAL'), ('3', 'CARDINAL'), ('Paris Saint Germain 1', 'ORG')], [('Paris Saint Germain', 'FAC'), ('Marco Verratti', 'PERSON'), ('Idrissa Gueye', 'PERSON')], [('Paris Saint Germain', 'FAC'), ('Thiago Silva', 'PERSON')], [('Second', 'ORDINAL'), ('Half', 'CARDINAL'), ('3', 'CARDINAL'), ('Paris Saint Germain 1', 'ORG')], [], [('Paris Saint Germain', 'ORG'), ('half', 'CARDINAL')], [('Serhou Guirassy', 'PERSON')], [('Ander Herrera', 'ORG'), ('Paris Saint Germain', 'ORG')], [('Alexis Blin', 'PERSON')], [('Leandro Paredes', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('half', 'CARDINAL')], [('Juan Ferney Otero', 'PERSON')], [('Mitchel Bakker', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Mitchel Bakker', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Juan Ferney Otero', 'PERSON'), ('Serhou Guirassy', 'PERSON')], [('Edinson Cavani', 'ORG'), ('Paris Saint Germain', 'ORG'), ('six', 'CARDINAL'), ('Ander Herrera', 'ORG')], [('Gaël Kakuta', 'PERSON'), ('half', 'CARDINAL')], [('Leandro Paredes', 'ORG'), ('Paris Saint Germain', 'ORG')], [('Alexis Blin', 'PERSON')], [('Marco Verrat ...
# No article or events for https://www.bbc.com/sport/football/50537852
# No article or events for https://www.bbc.com/sport/football/50537859
# No article or events for https://www.bbc.com/sport/football/50537866
# No article or events for https://www.bbc.com/sport/football/50530546
# No article or events for https://www.bbc.com/sport/football/50530553
# No article or events for https://www.bbc.com/sport/football/50530560
# No article or events for https://www.bbc.com/sport/football/50530567
# No article or events for https://www.bbc.com/sport/football/50530574
# No article or events for https://www.bbc.com/sport/football/50530581
# No article or events for https://www.bbc.com/sport/football/50281868
# No article or events for https://www.bbc.com/sport/football/50281875
# No article or events for https://www.bbc.com/sport/football/50281882
# No article or events for https://www.bbc.com/sport/football/50274991
# No article or events for https://www.bbc.com/sport/football/50274998
# No article or events for https://www.bbc.com/sport/football/50275005
# No article or events for https://www.bbc.com/sport/football/50275012
# No article or events for https://www.bbc.com/sport/football/50275026
# https://www.bbc.com/sport/football/50270487
# {'Paris Saint Germain'}
# ['Lineups are announced and players are warming up.', 'First Half begins.', 'Attempt saved. Didier Ndong (Dijon) left footed shot from outside the box is saved in the bottom left corner. Assisted by Júlio Tavares.', 'Attempt saved. Júlio Tavares (Dijon) right footed shot from outside the box is saved in the bottom right corner. Assisted by Fouad Chafik.', 'Foul by Mounir Chouiar (Dijon).', 'Presnel Kimpembe (Paris Saint Germain) wins a free kick in the defensive half.', 'Mama Baldé (Dijon) wins a free kick in the defensive half.', 'Foul by Abdou Diallo (Paris Saint Germain).', 'Foul by Wesley Lautoa (Dijon).', 'Juan Bernat (Paris Saint Germain) wins a free kick in the attacking half.', 'Foul by Didier Ndong (Dijon).', 'Kylian Mbappé (Paris Saint Germain) wins a free kick on the left wing.', 'Didier Ndong (Dijon) is shown the yellow card for a bad foul.', 'Foul by Jhonder Cádiz (Dijon).', 'Presnel Kimpembe (Paris Saint Germain) wins a free kick in the defensive half.', 'Jhonder Cádiz (Dijon) is shown the yellow card for a bad foul.', 'Jhonder Cádiz (Dijon) wins a free kick in the attacking half.', 'Foul by Presnel Kimpembe (Paris Saint Germain).', 'Presnel Kimpembe (Paris Saint Germain) is shown the yellow card for a bad foul.', 'Attempt saved. Jhonder Cádiz (Dijon) header from the centre of the box is saved in the bottom left corner. Assisted by Mounir Chouiar.', 'Attempt missed. Júlio Tavares (Dijon) header from the centre of the box is too high.', 'Attempt saved. Jhonder Cádiz (Dijon) left footed shot from outside the box is saved in the centre of the goal.', 'Goal!  Dijon 0, Paris Saint Germain 1. Kylian Mbappé (Paris Saint Germain) right footed shot from the centre of the box to the bottom right corner. Assisted by Ángel Di María with a through ball.', 'Attempt saved. Mauro Icardi (Paris Saint Germain) right footed shot from the centre of the box is saved in the centre of the goal. Assisted by Ángel Di María with a through ball.', 'Substitution, Dijon. Romain Amalfitano replaces Senou Coulibaly because of an injury.', 'Substitution, Dijon. Hamza Mendyl replaces Fouad Chafik because of an injury.', 'Corner,  Dijon. Conceded by Abdou Diallo.', 'Attempt blocked. Bruno Ecuele Manga (Dijon) right footed shot from the centre of the box is blocked. Assisted by Mounir Chouiar with a cross.', 'Foul by Didier Ndong (Dijon).', 'Idrissa Gueye (Paris Saint Germain) wins a free kick in the defensive half.', 'Jhonder Cádiz (Dijon) wins a free kick in the attacking half.', 'Foul by Idrissa Gueye (Paris Saint Germain).', 'Foul by Wesley Lautoa (Dijon).', 'Ángel Di María (Paris Saint Germain) wins a free kick in the attacking half.', 'Attempt blocked. Ángel Di María (Paris Saint Germain) left footed shot from outside the box is blocked.', 'Offside, Paris Saint Germain. Ángel Di María tries a through ball, but Idrissa Gueye is caught offside.', 'Corner,  Paris Saint Germain. Conceded by Hamza Mendyl.', 'Attempt missed. Leandro Paredes (Paris Saint Germain) right footed shot from outside the box misses to the left. Assisted by Ángel Di María following a corner.', 'Attempt blocked. Hamza Mendyl (Dijon) left footed shot from the right side of the box is blocked.', 'Goal!  Dijon 1, Paris Saint Germain 1. Mounir Chouiar (Dijon) right footed shot from the centre of the box to the bottom right corner.', 'First Half ends, Dijon 1, Paris Saint Germain 1.', 'Second Half begins Dijon 1, Paris Saint Germain 1.', 'Goal!  Dijon 2, Paris Saint Germain 1. Jhonder Cádiz (Dijon) left footed shot from a difficult angle on the left to the centre of the goal.', 'Attempt blocked. Ángel Di María (Paris Saint Germain) left footed shot from the right side of the box is blocked.', 'Corner,  Paris Saint Germain. Conceded by Wesley Lautoa.', 'Attempt blocked. Presnel Kimpembe (Paris Saint Germain) header from the centre of the box is blocked. Assisted by Ángel Di María with a cross.', 'Substitution, Dijon. Stephy Mavididi replaces Mama Baldé.', 'Attempt blocked. Mauro  ...
# [[('First', 'ORDINAL'), ('Half', 'CARDINAL')], [('Júlio Tavares', 'PERSON')], [('Fouad Chafik', 'PERSON')], [], [('Presnel Kimpembe', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('half', 'CARDINAL')], [('half', 'CARDINAL')], [('Abdou Diallo', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Wesley Lautoa', 'PERSON')], [('Juan Bernat', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('half', 'CARDINAL')], [], [('Kylian Mbappé', 'PERSON'), ('Paris Saint Germain', 'ORG')], [], [('Jhonder Cádiz', 'PERSON')], [('Presnel Kimpembe', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('half', 'CARDINAL')], [('Jhonder Cádiz', 'PERSON')], [('Jhonder Cádiz', 'PERSON'), ('half', 'CARDINAL')], [('Presnel Kimpembe', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Presnel Kimpembe', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Jhonder Cádiz', 'PERSON'), ('Mounir Chouiar', 'PERSON')], [('Júlio Tavares', 'PERSON')], [('Jhonder Cádiz', 'PERSON')], [('0', 'DATE'), ('Paris Saint Germain 1', 'ORG'), ('Kylian Mbappé', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Ángel Di María', 'PERSON')], [('Mauro Icardi', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Ángel Di María', 'PERSON')], [('Amalfitano', 'PERSON'), ('Senou Coulibaly', 'PERSON')], [('Hamza Mendyl', 'PERSON'), ('Fouad Chafik', 'PERSON')], [('Abdou Diallo', 'PERSON')], [('Bruno Ecuele Manga', 'PERSON'), ('Mounir Chouiar', 'PERSON')], [], [('Idrissa Gueye', 'PERSON'), ('half', 'CARDINAL')], [('Jhonder Cádiz', 'PERSON'), ('half', 'CARDINAL')], [('Idrissa Gueye', 'PERSON')], [('Wesley Lautoa', 'PERSON')], [('Ángel Di María', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('half', 'CARDINAL')], [('Ángel Di María', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Paris Saint Germain', 'FAC'), ('Ángel Di María', 'PERSON'), ('Idrissa Gueye', 'PERSON')], [('Paris Saint Germain', 'FAC'), ('Hamza Mendyl', 'PERSON')], [('Leandro Paredes', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Ángel Di María', 'PERSON')], [('Hamza Mendyl', 'PERSON')], [('1', 'CARDINAL'), ('Paris Saint Germain 1', 'ORG')], [('First', 'ORDINAL'), ('Half', 'CARDINAL'), ('1', 'CARDINAL'), ('Paris Saint Germain 1', 'ORG')], [('Second', 'ORDINAL'), ('Half', 'CARDINAL'), ('1', 'CARDINAL'), ('Paris Saint Germain 1', 'ORG')], [('2', 'CARDINAL'), ('Paris Saint Germain 1', 'ORG'), ('Jhonder Cádiz', 'PERSON')], [('Ángel Di María', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Paris Saint Germain', 'FAC'), ('Wesley Lautoa', 'PERSON')], [('Presnel Kimpembe', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Ángel Di María', 'PERSON')], [('Mama Baldé', 'PERSON')], [('Mauro Icardi', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Colin Dagba', 'PERSON')], [('Ángel Di María', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Mauro Icardi', 'PERSON')], [('Ngonda Muzinga', 'PERSON')], [('Ángel Di María', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('half', 'CARDINAL')], [('Kylian Mbappé', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Abdou Diallo', 'PERSON')], [('Hamza Mendyl', 'PERSON')], [('Kylian Mbappé', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('half', 'CARDINAL')], [('Hamza Mendyl', 'PERSON')], [('Colin Dagba', 'PERSON')], [('Bruno Ecuele Manga', 'PERSON'), ('Mounir Chouiar', 'PERSON')], [('Stephy Mavididi', 'GPE')], [('Mauro Icardi', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('half', 'CARDINAL')], [('Ángel Di María', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Juan Bernat', 'PERSON')], [('Mauro Icardi', 'PERSON'), ('Paris Saint Germain', 'ORG')], [('Ángel Di María', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Kylian Mbappé', 'PERSON')], [('Jhonder Cádiz', 'PERSON')], [('Paris Saint Germain', 'ORG'), ('half', 'CARDINAL')], [('Mauro Icardi', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Kylian Mbappé', 'PERSON')], [('Paris Saint Germain', 'FAC'), ('Layvin Kurzawa', 'PERSON'), ('Juan Bernat', 'PERSON')], [('Ángel Di María', 'PERSON'), ('Paris Saint Germain', 'ORG'), ('Leandro Paredes', 'PERSON')], [('Júlio Tavares', 'PERSON'), ('half', 'CARDINAL')], [('Paris Saint Germain', ' ...
# CPU times: user 20.3 s, sys: 23.8 ms, total: 20.3 s
# Wall time: 20.3 s

# %%
len(tp.teams_players_dict)
# Out:
# 8

# %%
tp.teams_players_dict
# Out:
# {'Paris Saint Germain': {'Abdou Diallo',
#   'Ander Herrera',
#   'Benjamin Lecomte',
#   'Colin Dagba',
#   'Eric Maxim Choupo-Moting',
#   'Herrera',
#   'Idrissa Gueye',
#   'Juan Bernat',
#   'Julian Draxler',
#   'Kylian Mbappé',
#   'Layvin Kurzawa',
#   'Leandro Paredes',
#   'Marco Verratti',
#   'Mauro Icardi',
#   'Nianzou Kouassi',
#   'Pablo Sarabia',
#   'Presnel Kimpembe',
#   'Thiago Silva',
#   'Thilo Kehrer',
#   'Thomas Meunier',
#   'Ángel Di María'},
#  'Lille': {'Benjamin André',
#   'Gabriel',
#   'Jonathan Ikoné',
#   'José Fonte',
#   'Keylor Navas',
#   'Loïc Rémy',
#   'Luiz Araújo',
#   'Mehmet Zeki Çelik',
#   'Reinildo',
#   'Renato Sanches'},
#  'Montpellier': {'Ambroise Oyongo',
#   'Andy Delort',
#   'Arnaud Souquet',
#   'Damien Le Tallec',
#   'Daniel Congré',
#   'Florent Mollet',
#   'Gaetan Laborde',
#   'Joris Chotard',
#   'Téji Savanier'},
#  'Nantes': {'Abdoul Kader Bamba',
#   'Andrei Girotto',
#   'Charles Traoré',
#   'Cristian Benavente Bristol',
#   'Kader Bamba',
#   'Ludovic Blas',
#   'Mehdi Abeid',
#   'Moses Simon'},
#  'Bordeaux': {'Edinson Cavani',
#   'Enock Kwateng',
#   'Hwang Ui-Jo',
#   'Josh Maja',
#   'Loris Benito',
#   'Marquinhos',
#   'Nicolas de Preville',
#   'Samuel Kalu',
#   'Yacine Adli',
#   'Youssef Aït Bennasser',
#   'Youssouf Sabaly'},
#  'Nîmes': {'Benoit Costil', 'Laurent Koscielny'},
#  'Monaco': {'Adrien Silva',
#   'Benjamin Henrichs',
#   'Cesc Fàbregas',
#   'Gelson Martins',
#   'Kamil Glik',
#   'Keita',
#   'Wissam Ben Yedder'},
#  'Lyon': {'Kenny Tete',
#   'Lucas Tousart',
#   'Marcelo',
#   'Moussa Dembele',
#   'Thiago Mendes'}}

# %% [markdown]
# Debug

# %%
url = 'http://www.premierleague.com/match/22447'
season_file = 'premier_league_2017_2018.json'
season_dict = tp.all_files[season_file]
article_events_dict = season_dict[url]

# %%
article_events_dict
# Out:
# {'article': "Substitute Sam Vokes was the hero for Burnley as they came away from St Mary's Stadium with a 1-0 win that sent them sixth in the table.\nAfter a first half where both sides threatened but failed to find a breakthrough, Burnley manager Sean Dyche turned to Vokes in search of a winner midway through the second half.\nAnd his move paid off in the 81st minute as Vokes headed a Johann Berg Gudmunsson cross past Fraser Forster into the bottom-right corner of the goal.\nThe result drops Southampton to 13th with 13 points.\nSee: Southampton report | Burnley report",
#  'events': []}

# %%
en_events_text = tp.atp.entity_names_events(article_events_dict['events'])
en_events_proc = tp.teams_players_sets(en_events_text, season_file.split('.')[0])

# %%
en_events_proc
# Out:
# []

# %%
en_events_text
# Out:
# []
